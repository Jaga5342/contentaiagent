# %%
import warnings 
warnings.filterwarnings('ignore')

# %%
from crewai import Agent, Task, Crew
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from crewai import Agent, Task, Crew
#
# ModuleNotFoundError: No module named 'crewai'

# %%
# !pip install crewai
# Out:
# Requirement already satisfied: crewai in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (0.121.1)
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from crewai) (1.4.4)
# Requirement already satisfied: auth0-python>=4.7.1 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from crewai) (4.9.0)
# Requirement already satisfied: blinker>=1.9.0 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from crewai) (1.9.0)
# Requirement already satisfied: chromadb>=0.5.23 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from crewai) (1.0.11)
# Requirement already satisfied: click>=8.1.7 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from crewai) (8.2.1)
# Requirement already satisfied: instructor>=1.3.3 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from crewai) (1.8.3)
# Requirement already satisfied: json-repair>=0.25.2 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from crewai) (0.46.0)
# Requirement already satisfied: json5>=0.10.0 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from crewai) (0.12.0)
# Requirement already satisfied: jsonref>=1.1.0 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from crewai) (1.1.0)
# Requirement already satisfied: litellm==1.68.0 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from crewai) (1.68.0)
# Requirement already satisfied: openai>=1.13.3 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from crewai) (1.75.0)
# Requirement already satisfied: openpyxl>=3.1.5 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from crewai) (3.1.5)
# Requirement already satisfied: opentelemetry-api>=1.30.0 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from crewai) (1.33.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http>=1.30.0 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from crewai) (1.33.1)
# Requirement already satisfied: opentelemetry-sdk>=1.30.0 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from crewai) (1.33.1)
# Requirement already satisfied: pdfplumber>=0.11.4 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from crewai) (0.11.6)
# Requirement already satisfied: pydantic>=2.4.2 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from crewai) (2.11.5)
# Requirement already satisfied: python-dotenv>=1.0.0 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from crewai) (1.1.0)
# Requirement already satisfied: pyvis>=0.3.2 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from crewai) (0.3.2)
# Requirement already satisfied: regex>=2024.9.11 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from crewai) (2024.11.6)
# Requirement already satisfied: tomli-w>=1.1.0 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from crewai) (1.2.0)
# Requirement already satisfied: tomli>=2.0.2 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from crewai) (2.2.1)
# Requirement already satisfied: uv>=0.4.25 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from crewai) (0.7.8)
# Requirement already satisfied: aiohttp in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from litellm==1.68.0->crewai) (3.12.4)
# Requirement already satisfied: httpx>=0.23.0 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from litellm==1.68.0->crewai) (0.28.1)
# Requirement already satisfied: importlib-metadata>=6.8.0 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from litellm==1.68.0->crewai) (8.6.1)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.2 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from litellm==1.68.0->crewai) (3.1.6)
# Requirement already satisfied: jsonschema<5.0.0,>=4.22.0 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from litellm==1.68.0->crewai) (4.24.0)
# Requirement already satisfied: tiktoken>=0.7.0 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from litellm==1.68.0->crewai) (0.9.0)
# Requirement already satisfied: tokenizers in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from litellm==1.68.0->crewai) (0.21.1)
# Requirement already satisfied: cryptography>=43.0.1 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from auth0-python>=4.7.1->crewai) (45.0.3)
# Requirement already satisfied: pyjwt>=2.8.0 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from auth0-python>=4.7.1->crewai) (2.10.1)
# Requirement already satisfied: requests>=2.32.3 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from auth0-python>=4.7.1->crewai) (2.32.3)
# Requirement already satisfied: urllib3>=2.2.3 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from auth0-python>=4.7.1->crewai) (2.4.0)
# Requirement already satisfied: build>=1.0.3 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from chromadb>=0.5.23->crewai) (1.2.2.post1)
# Requirement already satisfied: fastapi==0.115.9 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from chromadb>=0.5.23->crewai) (0.115.9)
# Requirement already satisfied: uvicorn[standard]>=0.18.3 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from chromadb>=0.5.23->crewai) (0.34.2)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from chromadb>=0.5.23->crewai) (2.2.6)
# Requirement already satisfied: posthog>=2.4.0 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from chromadb>=0.5.23->crewai) (4.2.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from chromadb>=0.5.23->crewai) (4.13.2)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from chromadb>=0.5.23->crewai) (1.22.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from chromadb>=0.5.23->crewai) (1.33.1)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from chromadb>=0.5.23->crewai) (0.54b1)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from chromadb>=0.5.23->crewai) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from chromadb>=0.5.23->crewai) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from chromadb>=0.5.23->crewai) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from chromadb>=0.5.23->crewai) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from chromadb>=0.5.23->crewai) (1.71.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from chromadb>=0.5.23->crewai) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from chromadb>=0.5.23->crewai) (0.16.0)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from chromadb>=0.5.23->crewai) (32.0.1)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from chromadb>=0.5.23->crewai) (9.1.2)
# Requirement already satisfied: pyyaml>=6.0.0 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from chromadb>=0.5.23->crewai) (6.0.2)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from chromadb>=0.5.23->crewai) (5.1.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from chromadb>=0.5.23->crewai) (3.10.18)
# Requirement already satisfied: rich>=10.11.0 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from chromadb>=0.5.23->crewai) (13.9.4)
# Requirement already satisfied: starlette<0.46.0,>=0.40.0 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from fastapi==0.115.9->chromadb>=0.5.23->crewai) (0.45.3)
# Requirement already satisfied: colorama in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from click>=8.1.7->crewai) (0.4.6)
# Requirement already satisfied: docstring-parser<1.0,>=0.16 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from instructor>=1.3.3->crewai) (0.16)
# Requirement already satisfied: jiter<0.9,>=0.6.1 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from instructor>=1.3.3->crewai) (0.8.2)
# Requirement already satisfied: pydantic-core<3.0.0,>=2.18.0 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from instructor>=1.3.3->crewai) (2.33.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from openai>=1.13.3->crewai) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from openai>=1.13.3->crewai) (1.9.0)
# Requirement already satisfied: sniffio in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from openai>=1.13.3->crewai) (1.3.1)
# Requirement already satisfied: et-xmlfile in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from openpyxl>=3.1.5->crewai) (2.0.0)
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-api>=1.30.0->crewai) (1.2.18)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-exporter-otlp-proto-http>=1.30.0->crewai) (1.70.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.33.1 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-exporter-otlp-proto-http>=1.30.0->crewai) (1.33.1)
# Requirement already satisfied: opentelemetry-proto==1.33.1 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-exporter-otlp-proto-http>=1.30.0->crewai) (1.33.1)
# Requirement already satisfied: protobuf<6.0,>=5.0 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-proto==1.33.1->opentelemetry-exporter-otlp-proto-http>=1.30.0->crewai) (5.29.5)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.54b1 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-sdk>=1.30.0->crewai) (0.54b1)
# Requirement already satisfied: pdfminer.six==20250327 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from pdfplumber>=0.11.4->crewai) (20250327)
# Requirement already satisfied: Pillow>=9.1 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from pdfplumber>=0.11.4->crewai) (11.2.1)
# Requirement already satisfied: pypdfium2>=4.18.0 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from pdfplumber>=0.11.4->crewai) (4.30.1)
# Requirement already satisfied: charset-normalizer>=2.0.0 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from pdfminer.six==20250327->pdfplumber>=0.11.4->crewai) (3.4.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from pydantic>=2.4.2->crewai) (0.7.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from pydantic>=2.4.2->crewai) (0.4.1)
# Requirement already satisfied: ipython>=5.3.0 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from pyvis>=0.3.2->crewai) (9.2.0)
# Requirement already satisfied: jsonpickle>=1.4.1 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from pyvis>=0.3.2->crewai) (4.1.0)
# Requirement already satisfied: networkx>=1.11 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from pyvis>=0.3.2->crewai) (3.4.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->litellm==1.68.0->crewai) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->litellm==1.68.0->crewai) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->litellm==1.68.0->crewai) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->litellm==1.68.0->crewai) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->litellm==1.68.0->crewai) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->litellm==1.68.0->crewai) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->litellm==1.68.0->crewai) (1.20.0)
# Requirement already satisfied: idna>=2.8 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from anyio<5,>=3.5.0->openai>=1.13.3->crewai) (3.10)
# Requirement already satisfied: packaging>=19.1 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from build>=1.0.3->chromadb>=0.5.23->crewai) (25.0)
# Requirement already satisfied: pyproject_hooks in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from build>=1.0.3->chromadb>=0.5.23->crewai) (1.2.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from cryptography>=43.0.1->auth0-python>=4.7.1->crewai) (1.17.1)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from deprecated>=1.2.6->opentelemetry-api>=1.30.0->crewai) (1.17.2)
# Requirement already satisfied: certifi in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.23.0->litellm==1.68.0->crewai) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.23.0->litellm==1.68.0->crewai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from httpcore==1.*->httpx>=0.23.0->litellm==1.68.0->crewai) (0.16.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from importlib-metadata>=6.8.0->litellm==1.68.0->crewai) (3.22.0)
# Requirement already satisfied: decorator in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (2.19.1)
# Requirement already satisfied: stack_data in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (5.14.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from jinja2<4.0.0,>=3.1.2->litellm==1.68.0->crewai) (3.0.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from jsonschema<5.0.0,>=4.22.0->litellm==1.68.0->crewai) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from jsonschema<5.0.0,>=4.22.0->litellm==1.68.0->crewai) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from jsonschema<5.0.0,>=4.22.0->litellm==1.68.0->crewai) (0.25.1)
# Requirement already satisfied: six>=1.9.0 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (2.40.2)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (1.8.0)
# Requirement already satisfied: requests-oauthlib in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (3.2.2)
# Requirement already satisfied: durationpy>=0.7 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (0.10)
# Requirement already satisfied: coloredlogs in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from onnxruntime>=1.14.1->chromadb>=0.5.23->crewai) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from onnxruntime>=1.14.1->chromadb>=0.5.23->crewai) (25.2.10)
# Requirement already satisfied: sympy in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from onnxruntime>=1.14.1->chromadb>=0.5.23->crewai) (1.14.0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.54b1 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.23->crewai) (0.54b1)
# Requirement already satisfied: opentelemetry-instrumentation==0.54b1 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.23->crewai) (0.54b1)
# Requirement already satisfied: opentelemetry-util-http==0.54b1 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.23->crewai) (0.54b1)
# Requirement already satisfied: asgiref~=3.0 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-instrumentation-asgi==0.54b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.23->crewai) (3.8.1)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from posthog>=2.4.0->chromadb>=0.5.23->crewai) (2.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from rich>=10.11.0->chromadb>=0.5.23->crewai) (3.0.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from tokenizers->litellm==1.68.0->crewai) (0.32.2)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from typer>=0.9.0->chromadb>=0.5.23->crewai) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai) (0.6.4)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai) (1.0.5)
# Requirement already satisfied: websockets>=10.4 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai) (15.0.1)
# Requirement already satisfied: pycparser in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from cffi>=1.14->cryptography>=43.0.1->auth0-python>=4.7.1->crewai) (2.22)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (4.9.1)
# Requirement already satisfied: filelock in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers->litellm==1.68.0->crewai) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers->litellm==1.68.0->crewai) (2025.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from jedi>=0.16->ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.8.4)
# Requirement already satisfied: mdurl~=0.1 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb>=0.5.23->crewai) (0.1.2)
# Requirement already satisfied: wcwidth in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.2.13)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb>=0.5.23->crewai) (10.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from stack_data->ipython>=5.3.0->pyvis>=0.3.2->crewai) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from stack_data->ipython>=5.3.0->pyvis>=0.3.2->crewai) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from stack_data->ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.2.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb>=0.5.23->crewai) (1.3.0)
# Requirement already satisfied: pyreadline3 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb>=0.5.23->crewai) (3.5.4)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (0.6.1)
# [notice] A new release of pip is available: 23.2.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !python -m pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\jagad\appdata\local\programs\python\python312\lib\site-packages (23.2.1)
# Collecting pip
#   Obtaining dependency information for pip from https://files.pythonhosted.org/packages/29/a2/d40fb2460e883eca5199c62cfc2463fd261f760556ae6290f88488c362c0/pip-25.1.1-py3-none-any.whl.metadata
#   Using cached pip-25.1.1-py3-none-any.whl.metadata (3.6 kB)
# Using cached pip-25.1.1-py3-none-any.whl (1.8 MB)
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 23.2.1
#     Uninstalling pip-23.2.1:
#       Successfully uninstalled pip-23.2.1
# Successfully installed pip-25.1.1

# %%
from crewai import Agent, Task, Crew
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from crewai import Agent, Task, Crew
#
# ModuleNotFoundError: No module named 'crewai'

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\jagad\AppData\Local\Programs\Python\Python313\python.exe

# %%
pip install ipykernel
python -m ipykernel install --user --name=crewai-env
# Out:
#   Cell In[1], line 1
#     pip install ipykernel
#         ^
# SyntaxError: invalid syntax

# %%
import sys
# !{sys.executable} -m pip install crewai
# Out:
# ^C
# Collecting crewai
#   Using cached crewai-0.11.2-py3-none-any.whl.metadata (12 kB)
# Collecting instructor<0.6.0,>=0.5.2 (from crewai)
#   Using cached instructor-0.5.2-py3-none-any.whl.metadata (10 kB)
# Collecting langchain<0.2.0,>=0.1.0 (from crewai)
#   Using cached langchain-0.1.20-py3-none-any.whl.metadata (13 kB)
# Collecting langchain-openai<0.0.6,>=0.0.5 (from crewai)
#   Using cached langchain_openai-0.0.5-py3-none-any.whl.metadata (2.5 kB)
# Collecting openai<2.0.0,>=1.7.1 (from crewai)
#   Using cached openai-1.83.0-py3-none-any.whl.metadata (25 kB)
# Collecting opentelemetry-api<2.0.0,>=1.22.0 (from crewai)
#   Using cached opentelemetry_api-1.33.1-py3-none-any.whl.metadata (1.6 kB)
# Collecting opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0 (from crewai)
#   Using cached opentelemetry_exporter_otlp_proto_http-1.33.1-py3-none-any.whl.metadata (2.4 kB)
# Collecting opentelemetry-sdk<2.0.0,>=1.22.0 (from crewai)
#   Using cached opentelemetry_sdk-1.33.1-py3-none-any.whl.metadata (1.6 kB)
# Collecting pydantic<3.0.0,>=2.4.2 (from crewai)
#   Using cached pydantic-2.11.5-py3-none-any.whl.metadata (67 kB)
# Collecting regex<2024.0.0,>=2023.12.25 (from crewai)
#   Using cached regex-2023.12.25.tar.gz (394 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting aiohttp<4.0.0,>=3.9.1 (from instructor<0.6.0,>=0.5.2->crewai)
#   Using cached aiohttp-3.12.7-cp313-cp313-win_amd64.whl.metadata (7.9 kB)
# Collecting docstring-parser<0.16,>=0.15 (from instructor<0.6.0,>=0.5.2->crewai)
#   Using cached docstring_parser-0.15-py3-none-any.whl.metadata (2.4 kB)
# Collecting rich<14.0.0,>=13.7.0 (from instructor<0.6.0,>=0.5.2->crewai)
#   Using cached rich-13.9.4-py3-none-any.whl.metadata (18 kB)
# Collecting tenacity<9.0.0,>=8.2.3 (from instructor<0.6.0,>=0.5.2->crewai)
#   Using cached tenacity-8.5.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting typer<0.10.0,>=0.9.0 (from instructor<0.6.0,>=0.5.2->crewai)
#   Using cached typer-0.9.4-py3-none-any.whl.metadata (14 kB)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp<4.0.0,>=3.9.1->instructor<0.6.0,>=0.5.2->crewai)
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp<4.0.0,>=3.9.1->instructor<0.6.0,>=0.5.2->crewai)
#   Using cached aiosignal-1.3.2-py2.py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\jagad\appdata\local\programs\python\python313\lib\site-packages (from aiohttp<4.0.0,>=3.9.1->instructor<0.6.0,>=0.5.2->crewai) (25.3.0)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.9.1->instructor<0.6.0,>=0.5.2->crewai)
#   Using cached frozenlist-1.6.0-cp313-cp313-win_amd64.whl.metadata (16 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.9.1->instructor<0.6.0,>=0.5.2->crewai)
#   Using cached multidict-6.4.4-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# Collecting propcache>=0.2.0 (from aiohttp<4.0.0,>=3.9.1->instructor<0.6.0,>=0.5.2->crewai)
#   Using cached propcache-0.3.1-cp313-cp313-win_amd64.whl.metadata (11 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp<4.0.0,>=3.9.1->instructor<0.6.0,>=0.5.2->crewai)
#   Using cached yarl-1.20.0-cp313-cp313-win_amd64.whl.metadata (74 kB)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\jagad\appdata\local\programs\python\python313\lib\site-packages (from langchain<0.2.0,>=0.1.0->crewai) (6.0.2)
# Collecting SQLAlchemy<3,>=1.4 (from langchain<0.2.0,>=0.1.0->crewai)
#   Using cached sqlalchemy-2.0.41-cp313-cp313-win_amd64.whl.metadata (9.8 kB)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain<0.2.0,>=0.1.0->crewai)
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting langchain-community<0.1,>=0.0.38 (from langchain<0.2.0,>=0.1.0->crewai)
#   Using cached langchain_community-0.0.38-py3-none-any.whl.metadata (8.7 kB)
# Collecting langchain-core<0.2.0,>=0.1.52 (from langchain<0.2.0,>=0.1.0->crewai)
#   Using cached langchain_core-0.1.53-py3-none-any.whl.metadata (5.9 kB)
# Collecting langchain-text-splitters<0.1,>=0.0.1 (from langchain<0.2.0,>=0.1.0->crewai)
#   Using cached langchain_text_splitters-0.0.2-py3-none-any.whl.metadata (2.2 kB)
# Collecting langsmith<0.2.0,>=0.1.17 (from langchain<0.2.0,>=0.1.0->crewai)
#   Using cached langsmith-0.1.147-py3-none-any.whl.metadata (14 kB)
# Collecting numpy<2,>=1 (from langchain<0.2.0,>=0.1.0->crewai)
#   Using cached numpy-1.26.4.tar.gz (15.8 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'error'
#   error: subprocess-exited-with-error
#
#   Preparing metadata (pyproject.toml) did not run successfully.
#   exit code: 1
#
#   [21 lines of output]
#   + C:\Users\jagad\AppData\Local\Programs\Python\Python313\python.exe C:\Users\jagad\AppData\Local\Temp\pip-install-sklnyv9o\numpy_1e586939a6cb474ba799857db073c4d8\vendored-meson\meson\meson.py setup C:\Users\jagad\AppData\Local\Temp\pip-install-sklnyv9o\numpy_1e586939a6cb474ba799857db073c4d8 C:\Users\jagad\AppData\Local\Temp\pip-install-sklnyv9o\numpy_1e586939a6cb474ba799857db073c4d8\.mesonpy-oouaubi4 -Dbuildtype=release -Db_ndebug=if-release -Db_vscrt=md --native-file=C:\Users\jagad\AppData\Local\Temp\pip-install-sklnyv9o\numpy_1e586939a6cb474ba799857db073c4d8\.mesonpy-oouaubi4\meson-python-native-file.ini
#   The Meson build system
#   Version: 1.2.99
#   Source dir: C:\Users\jagad\AppData\Local\Temp\pip-install-sklnyv9o\numpy_1e586939a6cb474ba799857db073c4d8
#   Build dir: C:\Users\jagad\AppData\Local\Temp\pip-install-sklnyv9o\numpy_1e586939a6cb474ba799857db073c4d8\.mesonpy-oouaubi4
#   Build type: native build
#   Project name: NumPy
#   Project version: 1.26.4
#   WARNING: Failed to activate VS environment: Could not find C:\Program Files (x86)\Microsoft Visual Studio\Installer\vswhere.exe
#
#   ..\meson.build:1:0: ERROR: Unknown compiler(s): [['icl'], ['cl'], ['cc'], ['gcc'], ['clang'], ['clang-cl'], ['pgcc']]
#   The following exception(s) were encountered:
#   Running `icl ""` gave "[WinError 2] The system cannot find the file specified"
#   Running `cl /?` gave "[WinError 2] The system cannot find the file specified"
#   Running `cc --version` gave "[WinError 2] The system cannot find the file specified"
#   Running `gcc --version` gave "[WinError 2] The system cannot find the file specified"
#   Running `clang --version` gave "[WinError 2] The system cannot find the file specified"
#   Running `clang-cl /?` gave "[WinError 2] The system cannot find the file specified"
#   Running `pgcc --version` gave "[WinError 2] The system cannot find the file specified"
#
#   A full log can be found at C:\Users\jagad\AppData\Local\Temp\pip-install-sklnyv9o\numpy_1e586939a6cb474ba799857db073c4d8\.mesonpy-oouaubi4\meson-logs\meson-log.txt
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# Encountered error while generating package metadata.
#
# See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
from crewai import Agent, Task, Crew

# %%
# ✅ Install required packages if not already installed (only if running locally)
# !pip install crewai==0.28.8 crewai_tools==0.1.6 langchain_community==0.0.29

# ✅ Setup
import os
import warnings
warnings.filterwarnings('ignore')

from crewai import Agent, Task, Crew
from utils import get_openai_api_key
openai_api_key = get_openai_api_key()
os.environ["OPENAI_MODEL_NAME"] = "gpt-3.5-turbo"

# ✅ Define Agents

planner = Agent(
    role="Content Planner",
    goal="Plan informative, well-structured, and audience-friendly content on {topic}",
    backstory="You're a planner creating a content structure with Introduction, What/Why/Where, Benefits, Applications, and Conclusion for a blog post on {topic}.",
    allow_delegation=False,
    verbose=True
)

writer = Agent(
    role="Content Writer",
    goal="Write clear, helpful, and easy-to-understand content based on the planner's outline",
    backstory="You're a writer drafting content based on the planner's structure using simple language and informative insights.",
    allow_delegation=False,
    verbose=True
)

editor = Agent(
    role="Content Editor",
    goal="Edit and enhance the clarity, tone, grammar, and structure of the article",
    backstory="You're an editor reviewing and improving the written content to ensure readability, correct grammar, and adherence to structure.",
    allow_delegation=False,
    verbose=True
)

plag_checker = Agent(
    role="Plagiarism Checker",
    goal="Check the article for any copied content and ensure originality",
    backstory="You're responsible for verifying that the content is original and flagging or suggesting changes to any potentially plagiarized segments.",
    allow_delegation=False,
    verbose=True
)

# ✅ Define Tasks

plan = Task(
    description=(
        "Create a content outline for a blog post on {topic} using this structure:\n"
        "1. Introduction\n"
        "2. What, Why, and Where\n"
        "3. Benefits\n"
        "4. Applications\n"
        "5. Conclusion\n"
        "Also include SEO keywords and target audience insights."
    ),
    expected_output="A content plan including an outline, SEO keywords, and target audience.",
    agent=planner,
)

write = Task(
    description=(
        "Write a clear and informative blog post on {topic} using the planner's outline. "
        "Use easy language. Ensure each section (Intro, What/Why/Where, Benefits, Applications, Conclusion) is 2-3 paragraphs long."
    ),
    expected_output="A draft article in markdown format with 5 sections, each having 2-3 paragraphs.",
    agent=writer,
)

check = Task(
    description=(
        "Scan the written content for plagiarism. Identify any potentially copied phrases and suggest replacements. "
        "Ensure the article is safe for publishing."
    ),
    expected_output="A markdown report with plagiarism findings and recommendations if needed.",
    agent=plag_checker,
)

edit = Task(
    description=(
        "Proofread the article. Improve clarity, structure, and grammar. Ensure tone is friendly and helpful. "
        "Make sure the blog matches the 5-part structure and is engaging to read."
    ),
    expected_output="Final edited article in markdown format, clean and reader-friendly.",
    agent=editor,
)

# ✅ Create Crew
crew = Crew(
    agents=[planner, writer, plag_checker, editor],
    tasks=[plan, write, check, edit],
    verbose=2  # Shows detailed logs
)

# ✅ Run the Agent System
result = crew.kickoff(inputs={"topic": "Art"})

# ✅ Show the Result
from IPython.display import Markdown
Markdown(result)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 10
#       7 warnings.filterwarnings('ignore')
#       9 from crewai import Agent, Task, Crew
# ---> 10 from utils import get_openai_api_key
#      11 openai_api_key = get_openai_api_key()
#      12 os.environ["OPENAI_MODEL_NAME"] = "gpt-3.5-turbo"
#
# ModuleNotFoundError: No module named 'utils'

# %%
from utils import get_openai_api_key
openai_api_key = get_openai_api_key()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from utils import get_openai_api_key
#       2 openai_api_key = get_openai_api_key()
#
# ModuleNotFoundError: No module named 'utils'

# %%
# ✅ Install required packages if not already installed (only if running locally)
# !pip install crewai==0.28.8 crewai_tools==0.1.6 langchain_community==0.0.29

# ✅ Setup
import os
import warnings
warnings.filterwarnings('ignore')

from crewai import Agent, Task, Crew
from utils import get_openai_api_key
openai_api_key = get_openai_api_key()
os.environ["OPENAI_MODEL_NAME"] = "gpt-3.5-turbo"

# ✅ Define Agents

planner = Agent(
    role="Content Planner",
    goal="Plan informative, well-structured, and audience-friendly content on {topic}",
    backstory="You're a planner creating a content structure with Introduction, What/Why/Where, Benefits, Applications, and Conclusion for a blog post on {topic}.",
    allow_delegation=False,
    verbose=True
)

writer = Agent(
    role="Content Writer",
    goal="Write clear, helpful, and easy-to-understand content based on the planner's outline",
    backstory="You're a writer drafting content based on the planner's structure using simple language and informative insights.",
    allow_delegation=False,
    verbose=True
)

editor = Agent(
    role="Content Editor",
    goal="Edit and enhance the clarity, tone, grammar, and structure of the article",
    backstory="You're an editor reviewing and improving the written content to ensure readability, correct grammar, and adherence to structure.",
    allow_delegation=False,
    verbose=True
)

plag_checker = Agent(
    role="Plagiarism Checker",
    goal="Check the article for any copied content and ensure originality",
    backstory="You're responsible for verifying that the content is original and flagging or suggesting changes to any potentially plagiarized segments.",
    allow_delegation=False,
    verbose=True
)

# ✅ Define Tasks

plan = Task(
    description=(
        "Create a content outline for a blog post on {topic} using this structure:\n"
        "1. Introduction\n"
        "2. What, Why, and Where\n"
        "3. Benefits\n"
        "4. Applications\n"
        "5. Conclusion\n"
        "Also include SEO keywords and target audience insights."
    ),
    expected_output="A content plan including an outline, SEO keywords, and target audience.",
    agent=planner,
)

write = Task(
    description=(
        "Write a clear and informative blog post on {topic} using the planner's outline. "
        "Use easy language. Ensure each section (Intro, What/Why/Where, Benefits, Applications, Conclusion) is 2-3 paragraphs long."
    ),
    expected_output="A draft article in markdown format with 5 sections, each having 2-3 paragraphs.",
    agent=writer,
)

check = Task(
    description=(
        "Scan the written content for plagiarism. Identify any potentially copied phrases and suggest replacements. "
        "Ensure the article is safe for publishing."
    ),
    expected_output="A markdown report with plagiarism findings and recommendations if needed.",
    agent=plag_checker,
)

edit = Task(
    description=(
        "Proofread the article. Improve clarity, structure, and grammar. Ensure tone is friendly and helpful. "
        "Make sure the blog matches the 5-part structure and is engaging to read."
    ),
    expected_output="Final edited article in markdown format, clean and reader-friendly.",
    agent=editor,
)

# ✅ Create Crew
crew = Crew(
    agents=[planner, writer, plag_checker, editor],
    tasks=[plan, write, check, edit],
    verbose=2  # Shows detailed logs
)

# ✅ Run the Agent System
result = crew.kickoff(inputs={"topic": "Art"})

# ✅ Show the Result
from IPython.display import Markdown
Markdown(result)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 10
#       7 warnings.filterwarnings('ignore')
#       9 from crewai import Agent, Task, Crew
# ---> 10 from utils import get_openai_api_key
#      11 openai_api_key = get_openai_api_key()
#      12 os.environ["OPENAI_MODEL_NAME"] = "gpt-3.5-turbo"
#
# ModuleNotFoundError: No module named 'utils'

# %%
from utils import get_openai_api_key
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from utils import get_openai_api_key
#
# ModuleNotFoundError: No module named 'utils'

# %%
# utils.py
import os

def get_openai_api_key():
    return os.getenv("OPENAI_API_KEY")

# %%
from utils import get_openai_api_key
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from utils import get_openai_api_key
#
# ModuleNotFoundError: No module named 'utils'

# %%
import importlib
import utils
importlib.reload(utils)

from utils import get_openai_api_key
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 2
#       1 import importlib
# ----> 2 import utils
#       3 importlib.reload(utils)
#       5 from utils import get_openai_api_key
#
# ModuleNotFoundError: No module named 'utils'

# %%
import importlib
import utils
importlib.reload(utils)

from utils import get_openai_api_key
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import importlib
# ----> 2 import utils
#       3 importlib.reload(utils)
#       5 from utils import get_openai_api_key
#
# ModuleNotFoundError: No module named 'utils'

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\jagad\OneDrive\Documents\AI Projects

# %%
from utils import get_openai_api_key
api_key = get_openai_api_key()
print(api_key)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from utils import get_openai_api_key
#       2 api_key = get_openai_api_key()
#       3 print(api_key)
#
# ModuleNotFoundError: No module named 'utils'

# %%
# ✅ Install required packages if not already installed (only if running locally)
# !pip install crewai==0.28.8 crewai_tools==0.1.6 langchain_community==0.0.29

# ✅ Setup
import os
import warnings
warnings.filterwarnings('ignore')

from crewai import Agent, Task, Crew
from utils import get_openai_api_key
openai_api_key = get_openai_api_key()
os.environ["OPENAI_MODEL_NAME"] = "gpt-3.5-turbo"

# ✅ Define Agents

planner = Agent(
    role="Content Planner",
    goal="Plan informative, well-structured, and audience-friendly content on {topic}",
    backstory="You're a planner creating a content structure with Introduction, What/Why/Where, Benefits, Applications, and Conclusion for a blog post on {topic}.",
    allow_delegation=False,
    verbose=True
)

writer = Agent(
    role="Content Writer",
    goal="Write clear, helpful, and easy-to-understand content based on the planner's outline",
    backstory="You're a writer drafting content based on the planner's structure using simple language and informative insights.",
    allow_delegation=False,
    verbose=True
)

editor = Agent(
    role="Content Editor",
    goal="Edit and enhance the clarity, tone, grammar, and structure of the article",
    backstory="You're an editor reviewing and improving the written content to ensure readability, correct grammar, and adherence to structure.",
    allow_delegation=False,
    verbose=True
)

plag_checker = Agent(
    role="Plagiarism Checker",
    goal="Check the article for any copied content and ensure originality",
    backstory="You're responsible for verifying that the content is original and flagging or suggesting changes to any potentially plagiarized segments.",
    allow_delegation=False,
    verbose=True
)

# ✅ Define Tasks

plan = Task(
    description=(
        "Create a content outline for a blog post on {topic} using this structure:\n"
        "1. Introduction\n"
        "2. What, Why, and Where\n"
        "3. Benefits\n"
        "4. Applications\n"
        "5. Conclusion\n"
        "Also include SEO keywords and target audience insights."
    ),
    expected_output="A content plan including an outline, SEO keywords, and target audience.",
    agent=planner,
)

write = Task(
    description=(
        "Write a clear and informative blog post on {topic} using the planner's outline. "
        "Use easy language. Ensure each section (Intro, What/Why/Where, Benefits, Applications, Conclusion) is 2-3 paragraphs long."
    ),
    expected_output="A draft article in markdown format with 5 sections, each having 2-3 paragraphs.",
    agent=writer,
)

check = Task(
    description=(
        "Scan the written content for plagiarism. Identify any potentially copied phrases and suggest replacements. "
        "Ensure the article is safe for publishing."
    ),
    expected_output="A markdown report with plagiarism findings and recommendations if needed.",
    agent=plag_checker,
)

edit = Task(
    description=(
        "Proofread the article. Improve clarity, structure, and grammar. Ensure tone is friendly and helpful. "
        "Make sure the blog matches the 5-part structure and is engaging to read."
    ),
    expected_output="Final edited article in markdown format, clean and reader-friendly.",
    agent=editor,
)

# ✅ Create Crew
crew = Crew(
    agents=[planner, writer, plag_checker, editor],
    tasks=[plan, write, check, edit],
    verbose=True  # Shows detailed logs
)

# ✅ Run the Agent System
result = crew.kickoff(inputs={"topic": "Art"})

# ✅ Show the Result
from IPython.display import Markdown
Markdown(result)
# Out:
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 8095f835-5200-4e61-8ac8-8fe08907395a                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# # Agent: Content Planner
# ## Task: Create a content outline for a blog post on Art using this structure:
# 1. Introduction
# 2. What, Why, and Where
# 3. Benefits
# 4. Applications
# 5. Conclusion
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.# Agent: Content Planner
# ## Task: Create a content outline for a blog post on Art using this structure:
# 1. Introduction
# 2. What, Why, and Where
# 3. Benefits
# 4. Applications
# 5. Conclusion
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.# Agent: Content Planner
# ## Task: Create a content outline for a blog post on Art using this structure:
# 1. Introduction
# 2. What, Why, and Where
# 3. Benefits
# 4. Applications
# 5. Conclusion
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# ...
#      41 if lines:
#      42     console = self.__console
# ---> 43     with console:
#      44         output = Text("\n").join(
#      45             self.__ansi_decoder.decode_line(line) for line in lines
#      46         )
#      47         console.print(output)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\rich\console.py:864, in Console.__exit__(self, exc_type, exc_value, traceback)
#     862 def __exit__(self, exc_type: Any, exc_value: Any, traceback: Any) -> None:
#     863     """Exit buffer context."""
# --> 864     self._exit_buffer()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\rich\console.py:822, in Console._exit_buffer(self)
#     820 """Leave buffer context, and render content if required."""
#     821 self._buffer_index -= 1
# --> 822 self._check_buffer()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\rich\console.py:2019, in Console._check_buffer(self)
#    2016     return
#    2018 try:
# -> 2019     self._write_buffer()
#    2020 except BrokenPipeError:
#    2021     self.on_broken_pipe()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\rich\console.py:2035, in Console._write_buffer(self)
#    2032 if self.is_jupyter:  # pragma: no cover
#    2033     from .jupyter import display
# -> 2035     display(self._buffer, self._render_buffer(self._buffer[:]))
#    2036     del self._buffer[:]
#    2037 else:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\rich\jupyter.py:91, in display(segments, text)
#      88 try:
#      89     from IPython.display import display as ipython_display
# ---> 91     ipython_display(jupyter_renderable)
#      92 except ModuleNotFoundError:
#      93     # Handle the case where the Console has force_jupyter=True,
#      94     # but IPython is not installed.
#      95     pass
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\display_functions.py:285, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     282         if metadata:
#     283             # kwarg-specified metadata gets precedence
#     284             _merge(md_dict, metadata)
# --> 285         publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#     286 if display_id:
#     287     return DisplayHandle(display_id)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\display_functions.py:73, in publish_display_data(data, metadata, transient, **kwargs)
#      70 if transient:
#      71     kwargs['transient'] = transient
# ---> 73 display_pub.publish(
#      74     data=data,
#      75     metadata=metadata,
#      76     **kwargs
#      77 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\zmqshell.py:103, in ZMQDisplayPublisher.publish(self, data, metadata, transient, update)
#      81 def publish(
#      82     self,
#      83     data,
#    (...)     86     update=False,
#      87 ):
#      88     """Publish a display-data message
#      89
#      90     Parameters
#    (...)    101         If True, send an update_display_data message instead of display_data.
#     102     """
# --> 103     self._flush_streams()
#     104     if metadata is None:
#     105         metadata = {}
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\zmqshell.py:66, in ZMQDisplayPublisher._flush_streams(self)
#      64 def _flush_streams(self):
#      65     """flush IO Streams prior to display"""
# ---> 66     sys.stdout.flush()
#      67     sys.stderr.flush()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\rich\file_proxy.py:53, in FileProxy.flush(self)
#      51 output = "".join(self.__buffer)
#      52 if output:
# ---> 53     self.__console.print(output)
#      54 del self.__buffer[:]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\rich\console.py:1678, in Console.print(self, sep, end, style, justify, overflow, no_wrap, emoji, markup, highlight, width, height, crop, soft_wrap, new_line_start, *objects)
#    1676     crop = False
#    1677 render_hooks = self._render_hooks[:]
# -> 1678 with self:
#    1679     renderables = self._collect_renderables(
#    1680         objects,
#    1681         sep,
#    (...)   1686         highlight=highlight,
#    1687     )
#    1688     for hook in render_hooks:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\rich\console.py:864, in Console.__exit__(self, exc_type, exc_value, traceback)
#     862 def __exit__(self, exc_type: Any, exc_value: Any, traceback: Any) -> None:
#     863     """Exit buffer context."""
# --> 864     self._exit_buffer()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\rich\console.py:822, in Console._exit_buffer(self)
#     820 """Leave buffer context, and render content if required."""
#     821 self._buffer_index -= 1
# --> 822 self._check_buffer()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\rich\console.py:2019, in Console._check_buffer(self)
#    2016     return
#    2018 try:
# -> 2019     self._write_buffer()
#    2020 except BrokenPipeError:
#    2021     self.on_broken_pipe()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\rich\console.py:2035, in Console._write_buffer(self)
#    2032 if self.is_jupyter:  # pragma: no cover
#    2033     from .jupyter import display
# -> 2035     display(self._buffer, self._render_buffer(self._buffer[:]))
#    2036     del self._buffer[:]
#    2037 else:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\rich\jupyter.py:91, in display(segments, text)
#      88 try:
#      89     from IPython.display import display as ipython_display
# ---> 91     ipython_display(jupyter_renderable)
#      92 except ModuleNotFoundError:
#      93     # Handle the case where the Console has force_jupyter=True,
#      94     # but IPython is not installed.
#      95     pass
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\display_functions.py:285, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     282         if metadata:
#     283             # kwarg-specified metadata gets precedence
#     284             _merge(md_dict, metadata)
# --> 285         publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#     286 if display_id:
#     287     return DisplayHandle(display_id)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\display_functions.py:73, in publish_display_data(data, metadata, transient, **kwargs)
#      70 if transient:
#      71     kwargs['transient'] = transient
# ---> 73 display_pub.publish(
#      74     data=data,
#      75     metadata=metadata,
#      76     **kwargs
#      77 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\zmqshell.py:103, in ZMQDisplayPublisher.publish(self, data, metadata, transient, update)
#      81 def publish(
#      82     self,
#      83     data,
#    (...)     86     update=False,
#      87 ):
#      88     """Publish a display-data message
#      89
#      90     Parameters
#    (...)    101         If True, send an update_display_data message instead of display_data.
#     102     """
# --> 103     self._flush_streams()
#     104     if metadata is None:
#     105         metadata = {}
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\zmqshell.py:66, in ZMQDisplayPublisher._flush_streams(self)
#      64 def _flush_streams(self):
#      65     """flush IO Streams prior to display"""
# ---> 66     sys.stdout.flush()
#      67     sys.stderr.flush()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\rich\file_proxy.py:53, in FileProxy.flush(self)
#      51 output = "".join(self.__buffer)
#      52 if output:
# ---> 53     self.__console.print(output)
#      54 del self.__buffer[:]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\rich\console.py:1678, in Console.print(self, sep, end, style, justify, overflow, no_wrap, emoji, markup, highlight, width, height, crop, soft_wrap, new_line_start, *objects)
#    1676     crop = False
#    1677 render_hooks = self._render_hooks[:]
# -> 1678 with self:
#    1679     renderables = self._collect_renderables(
#    1680         objects,
#    1681         sep,
#    (...)   1686         highlight=highlight,
#    1687     )
#    1688     for hook in render_hooks:
#
#     [... skipping similar frames: Console.__exit__ at line 864 (266 times), Console._check_buffer at line 2019 (266 times), Console._exit_buffer at line 822 (266 times), Console._write_buffer at line 2035 (266 times), display at line 91 (266 times), ZMQDisplayPublisher._flush_streams at line 66 (265 times), display at line 285 (265 times), FileProxy.flush at line 53 (265 times), Console.print at line 1678 (265 times), ZMQDisplayPublisher.publish at line 103 (265 times), publish_display_data at line 73 (265 times)]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\display_functions.py:285, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     282         if metadata:
#     283             # kwarg-specified metadata gets precedence
#     284             _merge(md_dict, metadata)
# --> 285         publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#     286 if display_id:
#     287     return DisplayHandle(display_id)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\display_functions.py:73, in publish_display_data(data, metadata, transient, **kwargs)
#      70 if transient:
#      71     kwargs['transient'] = transient
# ---> 73 display_pub.publish(
#      74     data=data,
#      75     metadata=metadata,
#      76     **kwargs
#      77 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\zmqshell.py:103, in ZMQDisplayPublisher.publish(self, data, metadata, transient, update)
#      81 def publish(
#      82     self,
#      83     data,
#    (...)     86     update=False,
#      87 ):
#      88     """Publish a display-data message
#      89
#      90     Parameters
#    (...)    101         If True, send an update_display_data message instead of display_data.
#     102     """
# --> 103     self._flush_streams()
#     104     if metadata is None:
#     105         metadata = {}
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\zmqshell.py:66, in ZMQDisplayPublisher._flush_streams(self)
#      64 def _flush_streams(self):
#      65     """flush IO Streams prior to display"""
# ---> 66     sys.stdout.flush()
#      67     sys.stderr.flush()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\rich\file_proxy.py:53, in FileProxy.flush(self)
#      51 output = "".join(self.__buffer)
#      52 if output:
# ---> 53     self.__console.print(output)
#      54 del self.__buffer[:]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\rich\console.py:1678, in Console.print(self, sep, end, style, justify, overflow, no_wrap, emoji, markup, highlight, width, height, crop, soft_wrap, new_line_start, *objects)
#    1676     crop = False
#    1677 render_hooks = self._render_hooks[:]
# -> 1678 with self:
#    1679     renderables = self._collect_renderables(
#    1680         objects,
#    1681         sep,
#    (...)   1686         highlight=highlight,
#    1687     )
#    1688     for hook in render_hooks:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\rich\console.py:864, in Console.__exit__(self, exc_type, exc_value, traceback)
#     862 def __exit__(self, exc_type: Any, exc_value: Any, traceback: Any) -> None:
#     863     """Exit buffer context."""
# --> 864     self._exit_buffer()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\rich\console.py:822, in Console._exit_buffer(self)
#     820 """Leave buffer context, and render content if required."""
#     821 self._buffer_index -= 1
# --> 822 self._check_buffer()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\rich\console.py:2019, in Console._check_buffer(self)
#    2016     return
#    2018 try:
# -> 2019     self._write_buffer()
#    2020 except BrokenPipeError:
#    2021     self.on_broken_pipe()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\rich\console.py:2035, in Console._write_buffer(self)
#    2032 if self.is_jupyter:  # pragma: no cover
#    2033     from .jupyter import display
# -> 2035     display(self._buffer, self._render_buffer(self._buffer[:]))
#    2036     del self._buffer[:]
#    2037 else:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\rich\jupyter.py:91, in display(segments, text)
#      88 try:
#      89     from IPython.display import display as ipython_display
# ---> 91     ipython_display(jupyter_renderable)
#      92 except ModuleNotFoundError:
#      93     # Handle the case where the Console has force_jupyter=True,
#      94     # but IPython is not installed.
#      95     pass
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\display_functions.py:278, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     276     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     277 else:
# --> 278     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     279     if not format_dict:
#     280         # nothing to display (e.g. _ipython_display_ took over)
#     281         continue
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\formatters.py:204, in DisplayFormatter.format(self, obj, include, exclude)
#     201 format_dict = {}
#     202 md_dict = {}
# --> 204 if self.ipython_display_formatter(obj):
#     205     # object handled itself, don't proceed
#     206     return {}, {}
#     208 format_dict, md_dict = self.mimebundle_formatter(obj, include=include, exclude=exclude)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\decorator.py:235, in decorate.<locals>.fun(*args, **kw)
#     233 if not kwsyntax:
#     234     args, kw = fix(args, kw, sig)
# --> 235 return caller(func, *(extras + args), **kw)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\formatters.py:290, in catch_format_error(method, self, *args, **kwargs)
#     288 ip = get_ipython()
#     289 if ip is not None:
# --> 290     ip.showtraceback(exc_info)
#     291 else:
#     292     traceback.print_exception(*exc_info)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py:2164, in InteractiveShell.showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2159         return False
#    2160     return isinstance(
#    2161         val, BaseExceptionGroup
#    2162     ) or contains_exceptiongroup(val.__context__)
# -> 2164 if contains_exceptiongroup(value):
#    2165     # fall back to native exception formatting until ultratb
#    2166     # supports exception groups
#    2167     traceback.print_exc()
#    2168 else:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py:2162, in InteractiveShell.showtraceback.<locals>.contains_exceptiongroup(val)
#    2158 if val is None:
#    2159     return False
#    2160 return isinstance(
#    2161     val, BaseExceptionGroup
# -> 2162 ) or contains_exceptiongroup(val.__context__)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py:2162, in InteractiveShell.showtraceback.<locals>.contains_exceptiongroup(val)
#    2158 if val is None:
#    2159     return False
#    2160 return isinstance(
#    2161     val, BaseExceptionGroup
# -> 2162 ) or contains_exceptiongroup(val.__context__)
#
#     [... skipping similar frames: InteractiveShell.showtraceback.<locals>.contains_exceptiongroup at line 2162 (2 times)]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py:2162, in InteractiveShell.showtraceback.<locals>.contains_exceptiongroup(val)
#    2158 if val is None:
#    2159     return False
#    2160 return isinstance(
#    2161     val, BaseExceptionGroup
# -> 2162 ) or contains_exceptiongroup(val.__context__)
#
# RecursionError: maximum recursion depth exceeded

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\jagad\OneDrive\Documents\AI Projects

# %%
import os
import warnings
warnings.filterwarnings('ignore')

from crewai import Agent, Task, Crew

# Optional: from your utils.py (if placed in same folder)
# from utils import get_openai_api_key
# openai_api_key = get_openai_api_key()
# os.environ["OPENAI_API_KEY"] = openai_api_key

# Setup (manual API key entry if not using .env)
os.environ["OPENAI_MODEL_NAME"] = "gpt-3.5-turbo"
os.environ["OPENAI_API_KEY"] = "sk-..."  # Replace with your real key

# Agents
planner = Agent(
    role="Content Planner",
    goal="Plan structured blog content about {topic}",
    backstory="You're a blog strategist designing content flow for a post.",
    allow_delegation=False,
    verbose=True
)

writer = Agent(
    role="Content Writer",
    goal="Write informative and engaging blog posts",
    backstory="You transform plans into clear blog content.",
    allow_delegation=False,
    verbose=True
)

editor = Agent(
    role="Content Editor",
    goal="Edit content for grammar, tone, and structure",
    backstory="You're an experienced editor refining drafts.",
    allow_delegation=False,
    verbose=True
)

# Tasks
plan = Task(
    description="Create a blog outline for the topic: {topic}. Include sections like Introduction, Importance, Benefits, Use Cases, and Conclusion.",
    expected_output="A structured content plan with 4–5 headers",
    agent=planner,
)

write = Task(
    description="Write the blog content based on the planner's structure. Make each section 2–3 paragraphs long and easy to read.",
    expected_output="Full markdown draft of blog post",
    agent=writer,
)

edit = Task(
    description="Proofread and enhance the blog post. Improve clarity, fix grammar, and make it engaging.",
    expected_output="Final polished version of blog post in markdown.",
    agent=editor,
)

# Crew
crew = Crew(
    agents=[planner, writer, editor],
    tasks=[plan, write, edit],
    verbose=True
)

# Run
result = crew.kickoff(inputs={"topic": "Art"})

# Display result
from IPython.display import Markdown
Markdown(result)
# Out:
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 8c420989-d65a-46f8-a15e-ceebfbd3f52c                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# # Agent: Content Planner
# ## Task: Create a blog outline for the topic: Art. Include sections like Introduction, Importance, Benefits, Use
# Cases, and Conclusion.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────────────── LLM Error ───────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  ❌ LLM Call Failed                                                                                             │
# │  Error: litellm.AuthenticationError: AuthenticationError: OpenAIException - Incorrect API key provided:         │
# │  sk-.... You can find your API key at https://platform.openai.com/account/api-keys.                             │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
#  An unknown error occurred. Please check the details below.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────────── Task Failure ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Failed                                                                                                    │
# │  Name: 3f87a8a9-b507-4d45-af29-c53ba66a3459                                                                     │
# │  Agent: Content Planner                                                                                         │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────────── Crew Failure ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Failed                                                                                          │
# │  Name: crew                                                                                                     │
# │  ID: 8c420989-d65a-46f8-a15e-ceebfbd3f52c                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\litellm\llms\openai\openai.py:724, in OpenAIChatCompletion.completion(self, model_response, timeout, optional_params, litellm_params, logging_obj, model, messages, print_verbose, api_key, api_base, api_version, dynamic_params, azure_ad_token, acompletion, logger_fn, headers, custom_prompt_dict, client, organization, custom_llm_provider, drop_params)
#     723             else:
# --> 724                 raise e
#     725 except OpenAIError as e:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\litellm\llms\openai\openai.py:652, in OpenAIChatCompletion.completion(self, model_response, timeout, optional_params, litellm_params, logging_obj, model, messages, print_verbose, api_key, api_base, api_version, dynamic_params, azure_ad_token, acompletion, logger_fn, headers, custom_prompt_dict, client, organization, custom_llm_provider, drop_params)
#     638 logging_obj.pre_call(
#     639     input=messages,
#     640     api_key=openai_client.api_key,
#    (...)    646     },
#     647 )
#     649 (
#     650     headers,
#     651     response,
# --> 652 ) = self.make_sync_openai_chat_completion_request(
#     653     openai_client=openai_client,
#     654     data=data,
#     655     timeout=timeout,
#     656     logging_obj=logging_obj,
#     657 )
#     659 logging_obj.model_call_details["response_headers"] = headers
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\litellm\litellm_core_utils\logging_utils.py:149, in track_llm_api_timing.<locals>.decorator.<locals>.sync_wrapper(*args, **kwargs)
#     148 try:
# --> 149     result = func(*args, **kwargs)
#     150     return result
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\litellm\llms\openai\openai.py:471, in OpenAIChatCompletion.make_sync_openai_chat_completion_request(self, openai_client, data, timeout, logging_obj)
#     470 else:
# --> 471     raise e
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\litellm\llms\openai\openai.py:453, in OpenAIChatCompletion.make_sync_openai_chat_completion_request(self, openai_client, data, timeout, logging_obj)
#     452 try:
# --> 453     raw_response = openai_client.chat.completions.with_raw_response.create(
#     454         **data, timeout=timeout
#     455     )
#     457     if hasattr(raw_response, "headers"):
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\openai\_legacy_response.py:364, in to_raw_response_wrapper.<locals>.wrapped(*args, **kwargs)
#     362 kwargs["extra_headers"] = extra_headers
# --> 364 return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\openai\_utils\_utils.py:279, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     278     raise TypeError(msg)
# --> 279 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\openai\resources\chat\completions\completions.py:929, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, reasoning_effort, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, web_search_options, extra_headers, extra_query, extra_body, timeout)
#     928 validate_response_format(response_format)
# --> 929 return self._post(
#     930     "/chat/completions",
#     931     body=maybe_transform(
#     932         {
#     933             "messages": messages,
#     934             "model": model,
#     935             "audio": audio,
#     936             "frequency_penalty": frequency_penalty,
#     937             "function_call": function_call,
#     938             "functions": functions,
#     939             "logit_bias": logit_bias,
#     940             "logprobs": logprobs,
#     941             "max_completion_tokens": max_completion_tokens,
#     942             "max_tokens": max_tokens,
#     943             "metadata": metadata,
#     944             "modalities": modalities,
#     945             "n": n,
#     946             "parallel_tool_calls": parallel_tool_calls,
#     947             "prediction": prediction,
#     948             "presence_penalty": presence_penalty,
#     949             "reasoning_effort": reasoning_effort,
#     950             "response_format": response_format,
#     951             "seed": seed,
#     952             "service_tier": service_tier,
#     953             "stop": stop,
#     954             "store": store,
#     955             "stream": stream,
#     956             "stream_options": stream_options,
#     957             "temperature": temperature,
#     958             "tool_choice": tool_choice,
#     959             "tools": tools,
#     960             "top_logprobs": top_logprobs,
#     961             "top_p": top_p,
#     962             "user": user,
#     963             "web_search_options": web_search_options,
#     964         },
#     965         completion_create_params.CompletionCreateParamsStreaming
#     966         if stream
#     967         else completion_create_params.CompletionCreateParamsNonStreaming,
#     968     ),
#     969     options=make_request_options(
#     970         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     971     ),
#     972     cast_to=ChatCompletion,
#     973     stream=stream or False,
#     974     stream_cls=Stream[ChatCompletionChunk],
#     975 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\openai\_base_client.py:1276, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1273 opts = FinalRequestOptions.construct(
#    1274     method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1275 )
# -> 1276 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\openai\_base_client.py:949, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     947     retries_taken = 0
# --> 949 return self._request(
#     950     cast_to=cast_to,
#     951     options=options,
#     952     stream=stream,
#     953     stream_cls=stream_cls,
#     954     retries_taken=retries_taken,
#     955 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\openai\_base_client.py:1057, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1056     log.debug("Re-raising status error")
# -> 1057     raise self._make_status_error_from_response(err.response) from None
#    1059 return self._process_response(
#    1060     cast_to=cast_to,
#    1061     options=options,
#    (...)   1065     retries_taken=retries_taken,
#    1066 )
#
# AuthenticationError: Error code: 401 - {'error': {'message': 'Incorrect API key provided: sk-.... You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
#
# During handling of the above exception, another exception occurred:
#
# OpenAIError                               Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\litellm\main.py:1831, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, deployment_id, extra_headers, functions, function_call, base_url, api_version, api_key, model_list, thinking, **kwargs)
#    1825     logging.post_call(
#    1826         input=messages,
#    1827         api_key=api_key,
#    1828         original_response=str(e),
#    1829         additional_args={"headers": headers},
#    1830     )
# -> 1831     raise e
#    1833 if optional_params.get("stream", False):
#    1834     ## LOGGING
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\litellm\main.py:1804, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, deployment_id, extra_headers, functions, function_call, base_url, api_version, api_key, model_list, thinking, **kwargs)
#    1803 try:
# -> 1804     response = openai_chat_completions.completion(
#    1805         model=model,
#    1806         messages=messages,
#    1807         headers=headers,
#    1808         model_response=model_response,
#    1809         print_verbose=print_verbose,
#    1810         api_key=api_key,
#    1811         api_base=api_base,
#    1812         acompletion=acompletion,
#    1813         logging_obj=logging,
#    1814         optional_params=optional_params,
#    1815         litellm_params=litellm_params,
#    1816         logger_fn=logger_fn,
#    1817         timeout=timeout,  # type: ignore
#    1818         custom_prompt_dict=custom_prompt_dict,
#    1819         client=client,  # pass AsyncOpenAI, OpenAI client
#    1820         organization=organization,
#    1821         custom_llm_provider=custom_llm_provider,
#    1822     )
#    1823 except Exception as e:
#    1824     ## LOGGING - log the original exception returned
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\litellm\llms\openai\openai.py:735, in OpenAIChatCompletion.completion(self, model_response, timeout, optional_params, litellm_params, logging_obj, model, messages, print_verbose, api_key, api_base, api_version, dynamic_params, azure_ad_token, acompletion, logger_fn, headers, custom_prompt_dict, client, organization, custom_llm_provider, drop_params)
#     734     error_headers = getattr(error_response, "headers", None)
# --> 735 raise OpenAIError(
#     736     status_code=status_code,
#     737     message=error_text,
#     738     headers=error_headers,
#     739     body=error_body,
#     740 )
#
# OpenAIError: Error code: 401 - {'error': {'message': 'Incorrect API key provided: sk-.... You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
#
# During handling of the above exception, another exception occurred:
#
# AuthenticationError                       Traceback (most recent call last)
# Cell In[3], line 68
#      61 crew = Crew(
#      62     agents=[planner, writer, editor],
#      63     tasks=[plan, write, edit],
#      64     verbose=True
#      65 )
#      67 # Run
# ---> 68 result = crew.kickoff(inputs={"topic": "Art"})
#      70 # Display result
#      71 from IPython.display import Markdown
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\crewai\crew.py:661, in Crew.kickoff(self, inputs)
#     658 metrics: List[UsageMetrics] = []
#     660 if self.process == Process.sequential:
# --> 661     result = self._run_sequential_process()
#     662 elif self.process == Process.hierarchical:
#     663     result = self._run_hierarchical_process()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\crewai\crew.py:773, in Crew._run_sequential_process(self)
#     771 def _run_sequential_process(self) -> CrewOutput:
#     772     """Executes tasks sequentially and returns the final output."""
# --> 773     return self._execute_tasks(self.tasks)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\crewai\crew.py:876, in Crew._execute_tasks(self, tasks, start_index, was_replayed)
#     873     futures.clear()
#     875 context = self._get_context(task, task_outputs)
# --> 876 task_output = task.execute_sync(
#     877     agent=agent_to_use,
#     878     context=context,
#     879     tools=cast(List[BaseTool], tools_for_task),
#     880 )
#     881 task_outputs.append(task_output)
#     882 self._process_task_result(task, task_output)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\crewai\task.py:351, in Task.execute_sync(self, agent, context, tools)
#     344 def execute_sync(
#     345     self,
#     346     agent: Optional[BaseAgent] = None,
#     347     context: Optional[str] = None,
#     348     tools: Optional[List[BaseTool]] = None,
#     349 ) -> TaskOutput:
#     350     """Execute the task synchronously."""
# --> 351     return self._execute_core(agent, context, tools)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\crewai\task.py:495, in Task._execute_core(self, agent, context, tools)
#     493 self.end_time = datetime.datetime.now()
#     494 crewai_event_bus.emit(self, TaskFailedEvent(error=str(e), task=self))
# --> 495 raise e
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\crewai\task.py:415, in Task._execute_core(self, agent, context, tools)
#     413 self.processed_by_agents.add(agent.role)
#     414 crewai_event_bus.emit(self, TaskStartedEvent(context=context, task=self))
# --> 415 result = agent.execute_task(
#     416     task=self,
#     417     context=context,
#     418     tools=tools,
#     419 )
#     421 pydantic_output, json_output = self._export_output(result)
#     422 task_output = TaskOutput(
#     423     name=self.name,
#     424     description=self.description,
#    (...)    430     output_format=self._get_output_format(),
#     431 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\crewai\agent.py:420, in Agent.execute_task(self, task, context, tools)
#     410 if e.__class__.__module__.startswith("litellm"):
#     411     # Do not retry on litellm errors
#     412     crewai_event_bus.emit(
#     413         self,
#     414         event=AgentExecutionErrorEvent(
#    (...)    418         ),
#     419     )
# --> 420     raise e
#     421 self._times_executed += 1
#     422 if self._times_executed > self.max_retry_limit:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\crewai\agent.py:396, in Agent.execute_task(self, task, context, tools)
#     392         result = self._execute_with_timeout(
#     393             task_prompt, task, self.max_execution_time
#     394         )
#     395     else:
# --> 396         result = self._execute_without_timeout(task_prompt, task)
#     398 except TimeoutError as e:
#     399     # Propagate TimeoutError without retry
#     400     crewai_event_bus.emit(
#     401         self,
#     402         event=AgentExecutionErrorEvent(
#    (...)    406         ),
#     407     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\crewai\agent.py:492, in Agent._execute_without_timeout(self, task_prompt, task)
#     482 def _execute_without_timeout(self, task_prompt: str, task: Task) -> str:
#     483     """Execute a task without a timeout.
#     484
#     485     Args:
#    (...)    490         The output of the agent.
#     491     """
# --> 492     return self.agent_executor.invoke(
#     493         {
#     494             "input": task_prompt,
#     495             "tool_names": self.agent_executor.tools_names,
#     496             "tools": self.agent_executor.tools_description,
#     497             "ask_for_human_input": task.human_input,
#     498         }
#     499     )["output"]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\crewai\agents\crew_agent_executor.py:121, in CrewAgentExecutor.invoke(self, inputs)
#     118 handle_unknown_error(self._printer, e)
#     119 if e.__class__.__module__.startswith("litellm"):
#     120     # Do not retry on litellm errors
# --> 121     raise e
#     122 else:
#     123     raise e
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\crewai\agents\crew_agent_executor.py:110, in CrewAgentExecutor.invoke(self, inputs)
#     107 self.ask_for_human_input = bool(inputs.get("ask_for_human_input", False))
#     109 try:
# --> 110     formatted_answer = self._invoke_loop()
#     111 except AssertionError:
#     112     self._printer.print(
#     113         content="Agent failed to reach a final answer. This is likely a bug - please report it.",
#     114         color="red",
#     115     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\crewai\agents\crew_agent_executor.py:206, in CrewAgentExecutor._invoke_loop(self)
#     203 except Exception as e:
#     204     if e.__class__.__module__.startswith("litellm"):
#     205         # Do not retry on litellm errors
# --> 206         raise e
#     207     if is_context_length_exceeded(e):
#     208         handle_context_length(
#     209             respect_context_window=self.respect_context_window,
#     210             printer=self._printer,
#    (...)    214             i18n=self._i18n,
#     215         )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\crewai\agents\crew_agent_executor.py:153, in CrewAgentExecutor._invoke_loop(self)
#     142     formatted_answer = handle_max_iterations_exceeded(
#     143         formatted_answer,
#     144         printer=self._printer,
#    (...)    148         callbacks=self.callbacks,
#     149     )
#     151 enforce_rpm_limit(self.request_within_rpm_limit)
# --> 153 answer = get_llm_response(
#     154     llm=self.llm,
#     155     messages=self.messages,
#     156     callbacks=self.callbacks,
#     157     printer=self._printer,
#     158 )
#     159 formatted_answer = process_llm_response(answer, self.use_stop_words)
#     161 if isinstance(formatted_answer, AgentAction):
#     162     # Extract agent fingerprint if available
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\crewai\utilities\agent_utils.py:157, in get_llm_response(llm, messages, callbacks, printer)
#     152 except Exception as e:
#     153     printer.print(
#     154         content=f"Error during LLM call: {e}",
#     155         color="red",
#     156     )
# --> 157     raise e
#     158 if not answer:
#     159     printer.print(
#     160         content="Received None or empty response from LLM call.",
#     161         color="red",
#     162     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\crewai\utilities\agent_utils.py:148, in get_llm_response(llm, messages, callbacks, printer)
#     146 """Call the LLM and return the response, handling any invalid responses."""
#     147 try:
# --> 148     answer = llm.call(
#     149         messages,
#     150         callbacks=callbacks,
#     151     )
#     152 except Exception as e:
#     153     printer.print(
#     154         content=f"Error during LLM call: {e}",
#     155         color="red",
#     156     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\crewai\llm.py:924, in LLM.call(self, messages, tools, callbacks, available_functions)
#     920         return self._handle_streaming_response(
#     921             params, callbacks, available_functions
#     922         )
#     923     else:
# --> 924         return self._handle_non_streaming_response(
#     925             params, callbacks, available_functions
#     926         )
#     928 except LLMContextLengthExceededException:
#     929     # Re-raise LLMContextLengthExceededException as it should be handled
#     930     # by the CrewAgentExecutor._invoke_loop method, which can then decide
#     931     # whether to summarize the content or abort based on the respect_context_window flag
#     932     raise
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\crewai\llm.py:763, in LLM._handle_non_streaming_response(self, params, callbacks, available_functions)
#     757 # --- 1) Make the completion call
#     758 try:
#     759     # Attempt to make the completion call, but catch context window errors
#     760     # and convert them to our own exception type for consistent handling
#     761     # across the codebase. This allows CrewAgentExecutor to handle context
#     762     # length issues appropriately.
# --> 763     response = litellm.completion(**params)
#     764 except ContextWindowExceededError as e:
#     765     # Convert litellm's context window error to our own exception type
#     766     # for consistent handling in the rest of the codebase
#     767     raise LLMContextLengthExceededException(str(e))
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\litellm\utils.py:1255, in client.<locals>.wrapper(*args, **kwargs)
#    1251 if logging_obj:
#    1252     logging_obj.failure_handler(
#    1253         e, traceback_exception, start_time, end_time
#    1254     )  # DO NOT MAKE THREADED - router retry fallback relies on this!
# -> 1255 raise e
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\litellm\utils.py:1133, in client.<locals>.wrapper(*args, **kwargs)
#    1131         print_verbose(f"Error while checking max token limit: {str(e)}")
#    1132 # MODEL CALL
# -> 1133 result = original_function(*args, **kwargs)
#    1134 end_time = datetime.datetime.now()
#    1135 if "stream" in kwargs and kwargs["stream"] is True:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\litellm\main.py:3216, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, deployment_id, extra_headers, functions, function_call, base_url, api_version, api_key, model_list, thinking, **kwargs)
#    3213     return response
#    3214 except Exception as e:
#    3215     ## Map to OpenAI Exception
# -> 3216     raise exception_type(
#    3217         model=model,
#    3218         custom_llm_provider=custom_llm_provider,
#    3219         original_exception=e,
#    3220         completion_kwargs=args,
#    3221         extra_kwargs=kwargs,
#    3222     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\litellm\litellm_core_utils\exception_mapping_utils.py:2224, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#    2222 if exception_mapping_worked:
#    2223     setattr(e, "litellm_response_headers", litellm_response_headers)
# -> 2224     raise e
#    2225 else:
#    2226     for error_type in litellm.LITELLM_EXCEPTION_TYPES:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\litellm\litellm_core_utils\exception_mapping_utils.py:396, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#     394 elif original_exception.status_code == 401:
#     395     exception_mapping_worked = True
# --> 396     raise AuthenticationError(
#     397         message=f"AuthenticationError: {exception_provider} - {message}",
#     398         llm_provider=custom_llm_provider,
#     399         model=model,
#     400         response=getattr(original_exception, "response", None),
#     401         litellm_debug_info=extra_information,
#     402     )
#     403 elif original_exception.status_code == 404:
#     404     exception_mapping_worked = True
#
# AuthenticationError: litellm.AuthenticationError: AuthenticationError: OpenAIException - Incorrect API key provided: sk-.... You can find your API key at https://platform.openai.com/account/api-keys.

# %%
# ✅ Setup
import os
import warnings
warnings.filterwarnings('ignore')

from crewai import Agent, Task, Crew
from utils import get_openai_api_key

# ✅ Load API key
openai_api_key = get_openai_api_key()
os.environ["OPENAI_API_KEY"] = openai_api_key
os.environ["OPENAI_MODEL_NAME"] = "gpt-3.5-turbo"

# ✅ Define Agents
planner = Agent(
    role="Content Planner",
    goal="Plan informative, well-structured, and audience-friendly content on {topic}",
    backstory="You're a planner who designs content structure for blog posts on {topic}, covering Intro, What/Why/Where, Benefits, Applications, and Conclusion.",
    allow_delegation=False,
    verbose=True
)

writer = Agent(
    role="Content Writer",
    goal="Write clear, helpful, and well-structured content based on the planner's outline",
    backstory="You craft engaging content from the planner's structure using simple language and insights.",
    allow_delegation=False,
    verbose=True
)

editor = Agent(
    role="Content Editor",
    goal="Polish and enhance clarity, tone, and grammar in the article",
    backstory="You're an expert editor who ensures the article flows well, with correct grammar and tone.",
    allow_delegation=False,
    verbose=True
)

plag_checker = Agent(
    role="Plagiarism Checker",
    goal="Ensure content originality by checking for potential plagiarism",
    backstory="You're responsible for verifying the content's originality and flagging copied content.",
    allow_delegation=False,
    verbose=True
)

# ✅ Define Tasks
plan = Task(
    description=(
        "Create a blog post outline for {topic} using this structure:\n"
        "1. Introduction\n"
        "2. What, Why, and Where\n"
        "3. Benefits\n"
        "4. Applications\n"
        "5. Conclusion\n"
        "Also include SEO keywords and target audience information."
    ),
    expected_output="A blog content plan with outline, keywords, and audience insights.",
    agent=planner
)

write = Task(
    description=(
        "Write a detailed blog post on {topic} following the planner's outline. "
        "Each section should contain 2-3 paragraphs. Use clear, reader-friendly language."
    ),
    expected_output="Draft blog article in markdown format with 5 main sections.",
    agent=writer
)

check = Task(
    description=(
        "Check the draft article for plagiarism. Identify copied phrases and suggest replacements. "
        "Ensure it's original and ready for publication."
    ),
    expected_output="Plagiarism report with findings and suggestions if needed.",
    agent=plag_checker
)

edit = Task(
    description=(
        "Edit the final article for grammar, tone, and readability. "
        "Ensure it aligns with the 5-part blog structure and feels engaging to readers."
    ),
    expected_output="Cleaned-up and polished article in markdown format.",
    agent=editor
)

# ✅ Create Crew
crew = Crew(
    agents=[planner, writer, plag_checker, editor],
    tasks=[plan, write, check, edit],
    verbose=True
)

# ✅ Run Agent System
result = crew.kickoff(inputs={"topic": "Art"})

# ✅ Show Result
from IPython.display import Markdown
Markdown(result)
# Out:
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: c20eb439-2fab-4807-b34a-eb5c9a29f368                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# # Agent: Content Planner
# ## Task: Create a blog post outline for Art using this structure:
# 1. Introduction
# 2. What, Why, and Where
# 3. Benefits
# 4. Applications
# 5. Conclusion
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.# Agent: Content Planner
# ## Task: Create a blog post outline for Art using this structure:
# 1. Introduction
# 2. What, Why, and Where
# 3. Benefits
# 4. Applications
# 5. Conclusion
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.# Agent: Content Planner
# ## Task: Create a blog post outline for Art using this structure:
# 1. Introduction
# 2. What, Why, and Where
# 3. Benefits
# 4. Applications
# 5. Conclusion
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# Also include SEO keywords and target audience information.[00m
# ...
#      41 if lines:
#      42     console = self.__console
# ---> 43     with console:
#      44         output = Text("\n").join(
#      45             self.__ansi_decoder.decode_line(line) for line in lines
#      46         )
#      47         console.print(output)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\rich\console.py:864, in Console.__exit__(self, exc_type, exc_value, traceback)
#     862 def __exit__(self, exc_type: Any, exc_value: Any, traceback: Any) -> None:
#     863     """Exit buffer context."""
# --> 864     self._exit_buffer()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\rich\console.py:822, in Console._exit_buffer(self)
#     820 """Leave buffer context, and render content if required."""
#     821 self._buffer_index -= 1
# --> 822 self._check_buffer()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\rich\console.py:2019, in Console._check_buffer(self)
#    2016     return
#    2018 try:
# -> 2019     self._write_buffer()
#    2020 except BrokenPipeError:
#    2021     self.on_broken_pipe()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\rich\console.py:2035, in Console._write_buffer(self)
#    2032 if self.is_jupyter:  # pragma: no cover
#    2033     from .jupyter import display
# -> 2035     display(self._buffer, self._render_buffer(self._buffer[:]))
#    2036     del self._buffer[:]
#    2037 else:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\rich\jupyter.py:91, in display(segments, text)
#      88 try:
#      89     from IPython.display import display as ipython_display
# ---> 91     ipython_display(jupyter_renderable)
#      92 except ModuleNotFoundError:
#      93     # Handle the case where the Console has force_jupyter=True,
#      94     # but IPython is not installed.
#      95     pass
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\display_functions.py:285, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     282         if metadata:
#     283             # kwarg-specified metadata gets precedence
#     284             _merge(md_dict, metadata)
# --> 285         publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#     286 if display_id:
#     287     return DisplayHandle(display_id)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\display_functions.py:73, in publish_display_data(data, metadata, transient, **kwargs)
#      70 if transient:
#      71     kwargs['transient'] = transient
# ---> 73 display_pub.publish(
#      74     data=data,
#      75     metadata=metadata,
#      76     **kwargs
#      77 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\zmqshell.py:103, in ZMQDisplayPublisher.publish(self, data, metadata, transient, update)
#      81 def publish(
#      82     self,
#      83     data,
#    (...)     86     update=False,
#      87 ):
#      88     """Publish a display-data message
#      89
#      90     Parameters
#    (...)    101         If True, send an update_display_data message instead of display_data.
#     102     """
# --> 103     self._flush_streams()
#     104     if metadata is None:
#     105         metadata = {}
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\zmqshell.py:66, in ZMQDisplayPublisher._flush_streams(self)
#      64 def _flush_streams(self):
#      65     """flush IO Streams prior to display"""
# ---> 66     sys.stdout.flush()
#      67     sys.stderr.flush()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\rich\file_proxy.py:53, in FileProxy.flush(self)
#      51 output = "".join(self.__buffer)
#      52 if output:
# ---> 53     self.__console.print(output)
#      54 del self.__buffer[:]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\rich\console.py:1678, in Console.print(self, sep, end, style, justify, overflow, no_wrap, emoji, markup, highlight, width, height, crop, soft_wrap, new_line_start, *objects)
#    1676     crop = False
#    1677 render_hooks = self._render_hooks[:]
# -> 1678 with self:
#    1679     renderables = self._collect_renderables(
#    1680         objects,
#    1681         sep,
#    (...)   1686         highlight=highlight,
#    1687     )
#    1688     for hook in render_hooks:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\rich\console.py:864, in Console.__exit__(self, exc_type, exc_value, traceback)
#     862 def __exit__(self, exc_type: Any, exc_value: Any, traceback: Any) -> None:
#     863     """Exit buffer context."""
# --> 864     self._exit_buffer()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\rich\console.py:822, in Console._exit_buffer(self)
#     820 """Leave buffer context, and render content if required."""
#     821 self._buffer_index -= 1
# --> 822 self._check_buffer()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\rich\console.py:2019, in Console._check_buffer(self)
#    2016     return
#    2018 try:
# -> 2019     self._write_buffer()
#    2020 except BrokenPipeError:
#    2021     self.on_broken_pipe()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\rich\console.py:2035, in Console._write_buffer(self)
#    2032 if self.is_jupyter:  # pragma: no cover
#    2033     from .jupyter import display
# -> 2035     display(self._buffer, self._render_buffer(self._buffer[:]))
#    2036     del self._buffer[:]
#    2037 else:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\rich\jupyter.py:91, in display(segments, text)
#      88 try:
#      89     from IPython.display import display as ipython_display
# ---> 91     ipython_display(jupyter_renderable)
#      92 except ModuleNotFoundError:
#      93     # Handle the case where the Console has force_jupyter=True,
#      94     # but IPython is not installed.
#      95     pass
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\display_functions.py:285, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     282         if metadata:
#     283             # kwarg-specified metadata gets precedence
#     284             _merge(md_dict, metadata)
# --> 285         publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#     286 if display_id:
#     287     return DisplayHandle(display_id)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\display_functions.py:73, in publish_display_data(data, metadata, transient, **kwargs)
#      70 if transient:
#      71     kwargs['transient'] = transient
# ---> 73 display_pub.publish(
#      74     data=data,
#      75     metadata=metadata,
#      76     **kwargs
#      77 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\zmqshell.py:103, in ZMQDisplayPublisher.publish(self, data, metadata, transient, update)
#      81 def publish(
#      82     self,
#      83     data,
#    (...)     86     update=False,
#      87 ):
#      88     """Publish a display-data message
#      89
#      90     Parameters
#    (...)    101         If True, send an update_display_data message instead of display_data.
#     102     """
# --> 103     self._flush_streams()
#     104     if metadata is None:
#     105         metadata = {}
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\zmqshell.py:66, in ZMQDisplayPublisher._flush_streams(self)
#      64 def _flush_streams(self):
#      65     """flush IO Streams prior to display"""
# ---> 66     sys.stdout.flush()
#      67     sys.stderr.flush()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\rich\file_proxy.py:53, in FileProxy.flush(self)
#      51 output = "".join(self.__buffer)
#      52 if output:
# ---> 53     self.__console.print(output)
#      54 del self.__buffer[:]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\rich\console.py:1678, in Console.print(self, sep, end, style, justify, overflow, no_wrap, emoji, markup, highlight, width, height, crop, soft_wrap, new_line_start, *objects)
#    1676     crop = False
#    1677 render_hooks = self._render_hooks[:]
# -> 1678 with self:
#    1679     renderables = self._collect_renderables(
#    1680         objects,
#    1681         sep,
#    (...)   1686         highlight=highlight,
#    1687     )
#    1688     for hook in render_hooks:
#
#     [... skipping similar frames: Console.__exit__ at line 864 (266 times), Console._check_buffer at line 2019 (266 times), Console._exit_buffer at line 822 (266 times), Console._write_buffer at line 2035 (266 times), display at line 91 (266 times), ZMQDisplayPublisher._flush_streams at line 66 (265 times), display at line 285 (265 times), FileProxy.flush at line 53 (265 times), Console.print at line 1678 (265 times), ZMQDisplayPublisher.publish at line 103 (265 times), publish_display_data at line 73 (265 times)]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\display_functions.py:285, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     282         if metadata:
#     283             # kwarg-specified metadata gets precedence
#     284             _merge(md_dict, metadata)
# --> 285         publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#     286 if display_id:
#     287     return DisplayHandle(display_id)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\display_functions.py:73, in publish_display_data(data, metadata, transient, **kwargs)
#      70 if transient:
#      71     kwargs['transient'] = transient
# ---> 73 display_pub.publish(
#      74     data=data,
#      75     metadata=metadata,
#      76     **kwargs
#      77 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\zmqshell.py:103, in ZMQDisplayPublisher.publish(self, data, metadata, transient, update)
#      81 def publish(
#      82     self,
#      83     data,
#    (...)     86     update=False,
#      87 ):
#      88     """Publish a display-data message
#      89
#      90     Parameters
#    (...)    101         If True, send an update_display_data message instead of display_data.
#     102     """
# --> 103     self._flush_streams()
#     104     if metadata is None:
#     105         metadata = {}
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\zmqshell.py:66, in ZMQDisplayPublisher._flush_streams(self)
#      64 def _flush_streams(self):
#      65     """flush IO Streams prior to display"""
# ---> 66     sys.stdout.flush()
#      67     sys.stderr.flush()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\rich\file_proxy.py:53, in FileProxy.flush(self)
#      51 output = "".join(self.__buffer)
#      52 if output:
# ---> 53     self.__console.print(output)
#      54 del self.__buffer[:]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\rich\console.py:1678, in Console.print(self, sep, end, style, justify, overflow, no_wrap, emoji, markup, highlight, width, height, crop, soft_wrap, new_line_start, *objects)
#    1676     crop = False
#    1677 render_hooks = self._render_hooks[:]
# -> 1678 with self:
#    1679     renderables = self._collect_renderables(
#    1680         objects,
#    1681         sep,
#    (...)   1686         highlight=highlight,
#    1687     )
#    1688     for hook in render_hooks:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\rich\console.py:864, in Console.__exit__(self, exc_type, exc_value, traceback)
#     862 def __exit__(self, exc_type: Any, exc_value: Any, traceback: Any) -> None:
#     863     """Exit buffer context."""
# --> 864     self._exit_buffer()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\rich\console.py:822, in Console._exit_buffer(self)
#     820 """Leave buffer context, and render content if required."""
#     821 self._buffer_index -= 1
# --> 822 self._check_buffer()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\rich\console.py:2019, in Console._check_buffer(self)
#    2016     return
#    2018 try:
# -> 2019     self._write_buffer()
#    2020 except BrokenPipeError:
#    2021     self.on_broken_pipe()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\rich\console.py:2035, in Console._write_buffer(self)
#    2032 if self.is_jupyter:  # pragma: no cover
#    2033     from .jupyter import display
# -> 2035     display(self._buffer, self._render_buffer(self._buffer[:]))
#    2036     del self._buffer[:]
#    2037 else:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\rich\jupyter.py:91, in display(segments, text)
#      88 try:
#      89     from IPython.display import display as ipython_display
# ---> 91     ipython_display(jupyter_renderable)
#      92 except ModuleNotFoundError:
#      93     # Handle the case where the Console has force_jupyter=True,
#      94     # but IPython is not installed.
#      95     pass
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\display_functions.py:278, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     276     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     277 else:
# --> 278     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     279     if not format_dict:
#     280         # nothing to display (e.g. _ipython_display_ took over)
#     281         continue
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\formatters.py:204, in DisplayFormatter.format(self, obj, include, exclude)
#     201 format_dict = {}
#     202 md_dict = {}
# --> 204 if self.ipython_display_formatter(obj):
#     205     # object handled itself, don't proceed
#     206     return {}, {}
#     208 format_dict, md_dict = self.mimebundle_formatter(obj, include=include, exclude=exclude)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\decorator.py:235, in decorate.<locals>.fun(*args, **kw)
#     233 if not kwsyntax:
#     234     args, kw = fix(args, kw, sig)
# --> 235 return caller(func, *(extras + args), **kw)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\formatters.py:290, in catch_format_error(method, self, *args, **kwargs)
#     288 ip = get_ipython()
#     289 if ip is not None:
# --> 290     ip.showtraceback(exc_info)
#     291 else:
#     292     traceback.print_exception(*exc_info)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py:2164, in InteractiveShell.showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2159         return False
#    2160     return isinstance(
#    2161         val, BaseExceptionGroup
#    2162     ) or contains_exceptiongroup(val.__context__)
# -> 2164 if contains_exceptiongroup(value):
#    2165     # fall back to native exception formatting until ultratb
#    2166     # supports exception groups
#    2167     traceback.print_exc()
#    2168 else:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py:2162, in InteractiveShell.showtraceback.<locals>.contains_exceptiongroup(val)
#    2158 if val is None:
#    2159     return False
#    2160 return isinstance(
#    2161     val, BaseExceptionGroup
# -> 2162 ) or contains_exceptiongroup(val.__context__)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py:2162, in InteractiveShell.showtraceback.<locals>.contains_exceptiongroup(val)
#    2158 if val is None:
#    2159     return False
#    2160 return isinstance(
#    2161     val, BaseExceptionGroup
# -> 2162 ) or contains_exceptiongroup(val.__context__)
#
#     [... skipping similar frames: InteractiveShell.showtraceback.<locals>.contains_exceptiongroup at line 2162 (2 times)]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py:2162, in InteractiveShell.showtraceback.<locals>.contains_exceptiongroup(val)
#    2158 if val is None:
#    2159     return False
#    2160 return isinstance(
#    2161     val, BaseExceptionGroup
# -> 2162 ) or contains_exceptiongroup(val.__context__)
#
# RecursionError: maximum recursion depth exceeded

# %%
# ✅ Install required packages (uncomment and run if not installed)
# !pip install crewai==0.28.8 crewai_tools==0.1.6 langchain_community==0.0.29 python-dotenv

# ✅ Setup
import os
import warnings
warnings.filterwarnings('ignore')

from crewai import Agent, Task, Crew

# ✅ Manually set OpenAI API Key (or load using dotenv if you have a `.env`)
os.environ["OPENAI_API_KEY"] = "your-openai-api-key"
os.environ["OPENAI_MODEL_NAME"] = "gpt-3.5-turbo"

# ✅ Define Agents (avoid curly braces in strings that cause unresolved formatting loops)

planner = Agent(
    role="Content Planner",
    goal="Plan informative, well-structured, and audience-friendly content",
    backstory="You are a content planner who organizes topics into clear outlines.",
    allow_delegation=False,
    verbose=True
)

writer = Agent(
    role="Content Writer",
    goal="Write helpful content based on a clear outline",
    backstory="You write easy-to-read, informative content using provided outlines.",
    allow_delegation=False,
    verbose=True
)

editor = Agent(
    role="Content Editor",
    goal="Improve the clarity and structure of written content",
    backstory="You proofread and refine content to make it clean and engaging.",
    allow_delegation=False,
    verbose=True
)

plag_checker = Agent(
    role="Plagiarism Checker",
    goal="Ensure the content is original",
    backstory="You scan and check for plagiarism and suggest replacements if needed.",
    allow_delegation=False,
    verbose=True
)

# ✅ Define Tasks

plan = Task(
    description=(
        "Create a content outline for a blog post titled 'The Impact of Art on Society'. "
        "Include: Introduction, What/Why/Where, Benefits, Applications, Conclusion, and SEO suggestions."
    ),
    expected_output="An outline and keywords for a blog post.",
    agent=planner,
)

write = Task(
    description=(
        "Using the outline, write a blog post about 'The Impact of Art on Society'. "
        "Include 5 main sections with simple, informative language."
    ),
    expected_output="A draft blog post in markdown format.",
    agent=writer,
)

check = Task(
    description="Check the written post for plagiarism and originality.",
    expected_output="A plagiarism report with suggestions.",
    agent=plag_checker,
)

edit = Task(
    description="Proofread the article and enhance it for clarity and tone.",
    expected_output="The final, polished blog post in markdown.",
    agent=editor,
)

# ✅ Create Crew (use verbose=True instead of a number)
crew = Crew(
    agents=[planner, writer, plag_checker, editor],
    tasks=[plan, write, check, edit],
    verbose=True
)

# ✅ Run the Agent System
result = crew.kickoff(inputs={"topic": "The Impact of Art on Society"})

# ✅ Show Result
from IPython.display import Markdown
Markdown(result)
# Out:
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 4210aa23-1cc7-4d3d-b7ce-7f57d0cd1d13                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# # Agent: Content Planner
# ## Task: Create a content outline for a blog post titled 'The Impact of Art on Society'. Include: Introduction,
# What/Why/Where, Benefits, Applications, Conclusion, and SEO suggestions.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────────────── LLM Error ───────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  ❌ LLM Call Failed                                                                                             │
# │  Error: litellm.AuthenticationError: AuthenticationError: OpenAIException - Incorrect API key provided:         │
# │  your-ope*******-key. You can find your API key at https://platform.openai.com/account/api-keys.                │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
#  An unknown error occurred. Please check the details below.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────────── Task Failure ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Failed                                                                                                    │
# │  Name: 70a3ac70-2e3b-4925-ac01-44ab13f16850                                                                     │
# │  Agent: Content Planner                                                                                         │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────────── Crew Failure ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Failed                                                                                          │
# │  Name: crew                                                                                                     │
# │  ID: 4210aa23-1cc7-4d3d-b7ce-7f57d0cd1d13                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\litellm\llms\openai\openai.py:724, in OpenAIChatCompletion.completion(self, model_response, timeout, optional_params, litellm_params, logging_obj, model, messages, print_verbose, api_key, api_base, api_version, dynamic_params, azure_ad_token, acompletion, logger_fn, headers, custom_prompt_dict, client, organization, custom_llm_provider, drop_params)
#     723             else:
# --> 724                 raise e
#     725 except OpenAIError as e:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\litellm\llms\openai\openai.py:652, in OpenAIChatCompletion.completion(self, model_response, timeout, optional_params, litellm_params, logging_obj, model, messages, print_verbose, api_key, api_base, api_version, dynamic_params, azure_ad_token, acompletion, logger_fn, headers, custom_prompt_dict, client, organization, custom_llm_provider, drop_params)
#     638 logging_obj.pre_call(
#     639     input=messages,
#     640     api_key=openai_client.api_key,
#    (...)    646     },
#     647 )
#     649 (
#     650     headers,
#     651     response,
# --> 652 ) = self.make_sync_openai_chat_completion_request(
#     653     openai_client=openai_client,
#     654     data=data,
#     655     timeout=timeout,
#     656     logging_obj=logging_obj,
#     657 )
#     659 logging_obj.model_call_details["response_headers"] = headers
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\litellm\litellm_core_utils\logging_utils.py:149, in track_llm_api_timing.<locals>.decorator.<locals>.sync_wrapper(*args, **kwargs)
#     148 try:
# --> 149     result = func(*args, **kwargs)
#     150     return result
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\litellm\llms\openai\openai.py:471, in OpenAIChatCompletion.make_sync_openai_chat_completion_request(self, openai_client, data, timeout, logging_obj)
#     470 else:
# --> 471     raise e
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\litellm\llms\openai\openai.py:453, in OpenAIChatCompletion.make_sync_openai_chat_completion_request(self, openai_client, data, timeout, logging_obj)
#     452 try:
# --> 453     raw_response = openai_client.chat.completions.with_raw_response.create(
#     454         **data, timeout=timeout
#     455     )
#     457     if hasattr(raw_response, "headers"):
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\openai\_legacy_response.py:364, in to_raw_response_wrapper.<locals>.wrapped(*args, **kwargs)
#     362 kwargs["extra_headers"] = extra_headers
# --> 364 return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\openai\_utils\_utils.py:279, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     278     raise TypeError(msg)
# --> 279 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\openai\resources\chat\completions\completions.py:929, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, reasoning_effort, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, web_search_options, extra_headers, extra_query, extra_body, timeout)
#     928 validate_response_format(response_format)
# --> 929 return self._post(
#     930     "/chat/completions",
#     931     body=maybe_transform(
#     932         {
#     933             "messages": messages,
#     934             "model": model,
#     935             "audio": audio,
#     936             "frequency_penalty": frequency_penalty,
#     937             "function_call": function_call,
#     938             "functions": functions,
#     939             "logit_bias": logit_bias,
#     940             "logprobs": logprobs,
#     941             "max_completion_tokens": max_completion_tokens,
#     942             "max_tokens": max_tokens,
#     943             "metadata": metadata,
#     944             "modalities": modalities,
#     945             "n": n,
#     946             "parallel_tool_calls": parallel_tool_calls,
#     947             "prediction": prediction,
#     948             "presence_penalty": presence_penalty,
#     949             "reasoning_effort": reasoning_effort,
#     950             "response_format": response_format,
#     951             "seed": seed,
#     952             "service_tier": service_tier,
#     953             "stop": stop,
#     954             "store": store,
#     955             "stream": stream,
#     956             "stream_options": stream_options,
#     957             "temperature": temperature,
#     958             "tool_choice": tool_choice,
#     959             "tools": tools,
#     960             "top_logprobs": top_logprobs,
#     961             "top_p": top_p,
#     962             "user": user,
#     963             "web_search_options": web_search_options,
#     964         },
#     965         completion_create_params.CompletionCreateParamsStreaming
#     966         if stream
#     967         else completion_create_params.CompletionCreateParamsNonStreaming,
#     968     ),
#     969     options=make_request_options(
#     970         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     971     ),
#     972     cast_to=ChatCompletion,
#     973     stream=stream or False,
#     974     stream_cls=Stream[ChatCompletionChunk],
#     975 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\openai\_base_client.py:1276, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1273 opts = FinalRequestOptions.construct(
#    1274     method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1275 )
# -> 1276 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\openai\_base_client.py:949, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     947     retries_taken = 0
# --> 949 return self._request(
#     950     cast_to=cast_to,
#     951     options=options,
#     952     stream=stream,
#     953     stream_cls=stream_cls,
#     954     retries_taken=retries_taken,
#     955 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\openai\_base_client.py:1057, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1056     log.debug("Re-raising status error")
# -> 1057     raise self._make_status_error_from_response(err.response) from None
#    1059 return self._process_response(
#    1060     cast_to=cast_to,
#    1061     options=options,
#    (...)   1065     retries_taken=retries_taken,
#    1066 )
#
# AuthenticationError: Error code: 401 - {'error': {'message': 'Incorrect API key provided: your-ope*******-key. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
#
# During handling of the above exception, another exception occurred:
#
# OpenAIError                               Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\litellm\main.py:1831, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, deployment_id, extra_headers, functions, function_call, base_url, api_version, api_key, model_list, thinking, **kwargs)
#    1825     logging.post_call(
#    1826         input=messages,
#    1827         api_key=api_key,
#    1828         original_response=str(e),
#    1829         additional_args={"headers": headers},
#    1830     )
# -> 1831     raise e
#    1833 if optional_params.get("stream", False):
#    1834     ## LOGGING
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\litellm\main.py:1804, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, deployment_id, extra_headers, functions, function_call, base_url, api_version, api_key, model_list, thinking, **kwargs)
#    1803 try:
# -> 1804     response = openai_chat_completions.completion(
#    1805         model=model,
#    1806         messages=messages,
#    1807         headers=headers,
#    1808         model_response=model_response,
#    1809         print_verbose=print_verbose,
#    1810         api_key=api_key,
#    1811         api_base=api_base,
#    1812         acompletion=acompletion,
#    1813         logging_obj=logging,
#    1814         optional_params=optional_params,
#    1815         litellm_params=litellm_params,
#    1816         logger_fn=logger_fn,
#    1817         timeout=timeout,  # type: ignore
#    1818         custom_prompt_dict=custom_prompt_dict,
#    1819         client=client,  # pass AsyncOpenAI, OpenAI client
#    1820         organization=organization,
#    1821         custom_llm_provider=custom_llm_provider,
#    1822     )
#    1823 except Exception as e:
#    1824     ## LOGGING - log the original exception returned
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\litellm\llms\openai\openai.py:735, in OpenAIChatCompletion.completion(self, model_response, timeout, optional_params, litellm_params, logging_obj, model, messages, print_verbose, api_key, api_base, api_version, dynamic_params, azure_ad_token, acompletion, logger_fn, headers, custom_prompt_dict, client, organization, custom_llm_provider, drop_params)
#     734     error_headers = getattr(error_response, "headers", None)
# --> 735 raise OpenAIError(
#     736     status_code=status_code,
#     737     message=error_text,
#     738     headers=error_headers,
#     739     body=error_body,
#     740 )
#
# OpenAIError: Error code: 401 - {'error': {'message': 'Incorrect API key provided: your-ope*******-key. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
#
# During handling of the above exception, another exception occurred:
#
# AuthenticationError                       Traceback (most recent call last)
# Cell In[5], line 89
#      82 crew = Crew(
#      83     agents=[planner, writer, plag_checker, editor],
#      84     tasks=[plan, write, check, edit],
#      85     verbose=True
#      86 )
#      88 # ✅ Run the Agent System
# ---> 89 result = crew.kickoff(inputs={"topic": "The Impact of Art on Society"})
#      91 # ✅ Show Result
#      92 from IPython.display import Markdown
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\crewai\crew.py:661, in Crew.kickoff(self, inputs)
#     658 metrics: List[UsageMetrics] = []
#     660 if self.process == Process.sequential:
# --> 661     result = self._run_sequential_process()
#     662 elif self.process == Process.hierarchical:
#     663     result = self._run_hierarchical_process()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\crewai\crew.py:773, in Crew._run_sequential_process(self)
#     771 def _run_sequential_process(self) -> CrewOutput:
#     772     """Executes tasks sequentially and returns the final output."""
# --> 773     return self._execute_tasks(self.tasks)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\crewai\crew.py:876, in Crew._execute_tasks(self, tasks, start_index, was_replayed)
#     873     futures.clear()
#     875 context = self._get_context(task, task_outputs)
# --> 876 task_output = task.execute_sync(
#     877     agent=agent_to_use,
#     878     context=context,
#     879     tools=cast(List[BaseTool], tools_for_task),
#     880 )
#     881 task_outputs.append(task_output)
#     882 self._process_task_result(task, task_output)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\crewai\task.py:351, in Task.execute_sync(self, agent, context, tools)
#     344 def execute_sync(
#     345     self,
#     346     agent: Optional[BaseAgent] = None,
#     347     context: Optional[str] = None,
#     348     tools: Optional[List[BaseTool]] = None,
#     349 ) -> TaskOutput:
#     350     """Execute the task synchronously."""
# --> 351     return self._execute_core(agent, context, tools)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\crewai\task.py:495, in Task._execute_core(self, agent, context, tools)
#     493 self.end_time = datetime.datetime.now()
#     494 crewai_event_bus.emit(self, TaskFailedEvent(error=str(e), task=self))
# --> 495 raise e
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\crewai\task.py:415, in Task._execute_core(self, agent, context, tools)
#     413 self.processed_by_agents.add(agent.role)
#     414 crewai_event_bus.emit(self, TaskStartedEvent(context=context, task=self))
# --> 415 result = agent.execute_task(
#     416     task=self,
#     417     context=context,
#     418     tools=tools,
#     419 )
#     421 pydantic_output, json_output = self._export_output(result)
#     422 task_output = TaskOutput(
#     423     name=self.name,
#     424     description=self.description,
#    (...)    430     output_format=self._get_output_format(),
#     431 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\crewai\agent.py:420, in Agent.execute_task(self, task, context, tools)
#     410 if e.__class__.__module__.startswith("litellm"):
#     411     # Do not retry on litellm errors
#     412     crewai_event_bus.emit(
#     413         self,
#     414         event=AgentExecutionErrorEvent(
#    (...)    418         ),
#     419     )
# --> 420     raise e
#     421 self._times_executed += 1
#     422 if self._times_executed > self.max_retry_limit:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\crewai\agent.py:396, in Agent.execute_task(self, task, context, tools)
#     392         result = self._execute_with_timeout(
#     393             task_prompt, task, self.max_execution_time
#     394         )
#     395     else:
# --> 396         result = self._execute_without_timeout(task_prompt, task)
#     398 except TimeoutError as e:
#     399     # Propagate TimeoutError without retry
#     400     crewai_event_bus.emit(
#     401         self,
#     402         event=AgentExecutionErrorEvent(
#    (...)    406         ),
#     407     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\crewai\agent.py:492, in Agent._execute_without_timeout(self, task_prompt, task)
#     482 def _execute_without_timeout(self, task_prompt: str, task: Task) -> str:
#     483     """Execute a task without a timeout.
#     484
#     485     Args:
#    (...)    490         The output of the agent.
#     491     """
# --> 492     return self.agent_executor.invoke(
#     493         {
#     494             "input": task_prompt,
#     495             "tool_names": self.agent_executor.tools_names,
#     496             "tools": self.agent_executor.tools_description,
#     497             "ask_for_human_input": task.human_input,
#     498         }
#     499     )["output"]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\crewai\agents\crew_agent_executor.py:121, in CrewAgentExecutor.invoke(self, inputs)
#     118 handle_unknown_error(self._printer, e)
#     119 if e.__class__.__module__.startswith("litellm"):
#     120     # Do not retry on litellm errors
# --> 121     raise e
#     122 else:
#     123     raise e
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\crewai\agents\crew_agent_executor.py:110, in CrewAgentExecutor.invoke(self, inputs)
#     107 self.ask_for_human_input = bool(inputs.get("ask_for_human_input", False))
#     109 try:
# --> 110     formatted_answer = self._invoke_loop()
#     111 except AssertionError:
#     112     self._printer.print(
#     113         content="Agent failed to reach a final answer. This is likely a bug - please report it.",
#     114         color="red",
#     115     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\crewai\agents\crew_agent_executor.py:206, in CrewAgentExecutor._invoke_loop(self)
#     203 except Exception as e:
#     204     if e.__class__.__module__.startswith("litellm"):
#     205         # Do not retry on litellm errors
# --> 206         raise e
#     207     if is_context_length_exceeded(e):
#     208         handle_context_length(
#     209             respect_context_window=self.respect_context_window,
#     210             printer=self._printer,
#    (...)    214             i18n=self._i18n,
#     215         )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\crewai\agents\crew_agent_executor.py:153, in CrewAgentExecutor._invoke_loop(self)
#     142     formatted_answer = handle_max_iterations_exceeded(
#     143         formatted_answer,
#     144         printer=self._printer,
#    (...)    148         callbacks=self.callbacks,
#     149     )
#     151 enforce_rpm_limit(self.request_within_rpm_limit)
# --> 153 answer = get_llm_response(
#     154     llm=self.llm,
#     155     messages=self.messages,
#     156     callbacks=self.callbacks,
#     157     printer=self._printer,
#     158 )
#     159 formatted_answer = process_llm_response(answer, self.use_stop_words)
#     161 if isinstance(formatted_answer, AgentAction):
#     162     # Extract agent fingerprint if available
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\crewai\utilities\agent_utils.py:157, in get_llm_response(llm, messages, callbacks, printer)
#     152 except Exception as e:
#     153     printer.print(
#     154         content=f"Error during LLM call: {e}",
#     155         color="red",
#     156     )
# --> 157     raise e
#     158 if not answer:
#     159     printer.print(
#     160         content="Received None or empty response from LLM call.",
#     161         color="red",
#     162     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\crewai\utilities\agent_utils.py:148, in get_llm_response(llm, messages, callbacks, printer)
#     146 """Call the LLM and return the response, handling any invalid responses."""
#     147 try:
# --> 148     answer = llm.call(
#     149         messages,
#     150         callbacks=callbacks,
#     151     )
#     152 except Exception as e:
#     153     printer.print(
#     154         content=f"Error during LLM call: {e}",
#     155         color="red",
#     156     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\crewai\llm.py:924, in LLM.call(self, messages, tools, callbacks, available_functions)
#     920         return self._handle_streaming_response(
#     921             params, callbacks, available_functions
#     922         )
#     923     else:
# --> 924         return self._handle_non_streaming_response(
#     925             params, callbacks, available_functions
#     926         )
#     928 except LLMContextLengthExceededException:
#     929     # Re-raise LLMContextLengthExceededException as it should be handled
#     930     # by the CrewAgentExecutor._invoke_loop method, which can then decide
#     931     # whether to summarize the content or abort based on the respect_context_window flag
#     932     raise
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\crewai\llm.py:763, in LLM._handle_non_streaming_response(self, params, callbacks, available_functions)
#     757 # --- 1) Make the completion call
#     758 try:
#     759     # Attempt to make the completion call, but catch context window errors
#     760     # and convert them to our own exception type for consistent handling
#     761     # across the codebase. This allows CrewAgentExecutor to handle context
#     762     # length issues appropriately.
# --> 763     response = litellm.completion(**params)
#     764 except ContextWindowExceededError as e:
#     765     # Convert litellm's context window error to our own exception type
#     766     # for consistent handling in the rest of the codebase
#     767     raise LLMContextLengthExceededException(str(e))
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\litellm\utils.py:1255, in client.<locals>.wrapper(*args, **kwargs)
#    1251 if logging_obj:
#    1252     logging_obj.failure_handler(
#    1253         e, traceback_exception, start_time, end_time
#    1254     )  # DO NOT MAKE THREADED - router retry fallback relies on this!
# -> 1255 raise e
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\litellm\utils.py:1133, in client.<locals>.wrapper(*args, **kwargs)
#    1131         print_verbose(f"Error while checking max token limit: {str(e)}")
#    1132 # MODEL CALL
# -> 1133 result = original_function(*args, **kwargs)
#    1134 end_time = datetime.datetime.now()
#    1135 if "stream" in kwargs and kwargs["stream"] is True:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\litellm\main.py:3216, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, deployment_id, extra_headers, functions, function_call, base_url, api_version, api_key, model_list, thinking, **kwargs)
#    3213     return response
#    3214 except Exception as e:
#    3215     ## Map to OpenAI Exception
# -> 3216     raise exception_type(
#    3217         model=model,
#    3218         custom_llm_provider=custom_llm_provider,
#    3219         original_exception=e,
#    3220         completion_kwargs=args,
#    3221         extra_kwargs=kwargs,
#    3222     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\litellm\litellm_core_utils\exception_mapping_utils.py:2224, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#    2222 if exception_mapping_worked:
#    2223     setattr(e, "litellm_response_headers", litellm_response_headers)
# -> 2224     raise e
#    2225 else:
#    2226     for error_type in litellm.LITELLM_EXCEPTION_TYPES:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\litellm\litellm_core_utils\exception_mapping_utils.py:396, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#     394 elif original_exception.status_code == 401:
#     395     exception_mapping_worked = True
# --> 396     raise AuthenticationError(
#     397         message=f"AuthenticationError: {exception_provider} - {message}",
#     398         llm_provider=custom_llm_provider,
#     399         model=model,
#     400         response=getattr(original_exception, "response", None),
#     401         litellm_debug_info=extra_information,
#     402     )
#     403 elif original_exception.status_code == 404:
#     404     exception_mapping_worked = True
#
# AuthenticationError: litellm.AuthenticationError: AuthenticationError: OpenAIException - Incorrect API key provided: your-ope*******-key. You can find your API key at https://platform.openai.com/account/api-keys.

# %%
# ✅ Install required packages if not already installed (only if running locally)
# !pip install crewai==0.28.8 crewai_tools==0.1.6 langchain_community==0.0.29 > /dev/null
# !pip install openai > /dev/null

# ✅ Setup
import os
import warnings
warnings.filterwarnings('ignore')

from crewai import Agent, Task, Crew
from IPython.display import Markdown

# Set your OpenAI API key here
os.environ["OPENAI_API_KEY"] = "your-api-key-here"  # Replace with your actual API key
os.environ["OPENAI_MODEL_NAME"] = "gpt-3.5-turbo"

# ✅ Define Agents

planner = Agent(
    role="Content Planner",
    goal="Plan informative, well-structured, and audience-friendly content on {topic}",
    backstory="You're a planner creating a content structure with Introduction, What/Why/Where, Benefits, Applications, and Conclusion for a blog post on {topic}.",
    allow_delegation=False,
    verbose=True
)

writer = Agent(
    role="Content Writer",
    goal="Write clear, helpful, and easy-to-understand content based on the planner's outline",
    backstory="You're a writer drafting content based on the planner's structure using simple language and informative insights.",
    allow_delegation=False,
    verbose=True
)

editor = Agent(
    role="Content Editor",
    goal="Edit and enhance the clarity, tone, grammar, and structure of the article",
    backstory="You're an editor reviewing and improving the written content to ensure readability, correct grammar, and adherence to structure.",
    allow_delegation=False,
    verbose=True
)

plag_checker = Agent(
    role="Plagiarism Checker",
    goal="Check the article for any copied content and ensure originality",
    backstory="You're responsible for verifying that the content is original and flagging or suggesting changes to any potentially plagiarized segments.",
    allow_delegation=False,
    verbose=True
)

# ✅ Define Tasks

plan = Task(
    description=(
        "Create a content outline for a blog post on {topic} using this structure:\n"
        "1. Introduction\n"
        "2. What, Why, and Where\n"
        "3. Benefits\n"
        "4. Applications\n"
        "5. Conclusion\n"
        "Also include SEO keywords and target audience insights."
    ),
    expected_output="A content plan including an outline, SEO keywords, and target audience.",
    agent=planner,
)

write = Task(
    description=(
        "Write a clear and informative blog post on {topic} using the planner's outline. "
        "Use easy language. Ensure each section (Intro, What/Why/Where, Benefits, Applications, Conclusion) is 2-3 paragraphs long."
    ),
    expected_output="A draft article in markdown format with 5 sections, each having 2-3 paragraphs.",
    agent=writer,
)

check = Task(
    description=(
        "Scan the written content for plagiarism. Identify any potentially copied phrases and suggest replacements. "
        "Ensure the article is safe for publishing."
    ),
    expected_output="A markdown report with plagiarism findings and recommendations if needed.",
    agent=plag_checker,
)

edit = Task(
    description=(
        "Proofread the article. Improve clarity, structure, and grammar. Ensure tone is friendly and helpful. "
        "Make sure the blog matches the 5-part structure and is engaging to read."
    ),
    expected_output="Final edited article in markdown format, clean and reader-friendly.",
    agent=editor,
)

# ✅ Create Crew
crew = Crew(
    agents=[planner, writer, plag_checker, editor],
    tasks=[plan, write, check, edit],
    verbose=True  # Shows detailed logs
)

# ✅ Run the Agent System
result = crew.kickoff(inputs={"topic": "Artificial Intelligence in Healthcare"})

# ✅ Show the Result
Markdown(result)
# Out:
# The system cannot find the path specified.
# The system cannot find the path specified.
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 0466665d-c787-4c22-9716-90aa838f7f7b                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# # Agent: Content Planner
# ## Task: Create a content outline for a blog post on Artificial Intelligence in Healthcare using this structure:
# 1. Introduction
# 2. What, Why, and Where
# 3. Benefits
# 4. Applications
# 5. Conclusion
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.# Agent: Content Planner
# ## Task: Create a content outline for a blog post on Artificial Intelligence in Healthcare using this structure:
# 1. Introduction
# 2. What, Why, and Where
# 3. Benefits
# 4. Applications
# 5. Conclusion
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.# Agent: Content Planner
# ## Task: Create a content outline for a blog post on Artificial Intelligence in Healthcare using this structure:
# 1. Introduction
# 2. What, Why, and Where
# 3. Benefits
# 4. Applications
# 5. Conclusion
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# Also include SEO keywords and target audience insights.[00m
# ...
#      41 if lines:
#      42     console = self.__console
# ---> 43     with console:
#      44         output = Text("\n").join(
#      45             self.__ansi_decoder.decode_line(line) for line in lines
#      46         )
#      47         console.print(output)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\rich\console.py:864, in Console.__exit__(self, exc_type, exc_value, traceback)
#     862 def __exit__(self, exc_type: Any, exc_value: Any, traceback: Any) -> None:
#     863     """Exit buffer context."""
# --> 864     self._exit_buffer()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\rich\console.py:822, in Console._exit_buffer(self)
#     820 """Leave buffer context, and render content if required."""
#     821 self._buffer_index -= 1
# --> 822 self._check_buffer()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\rich\console.py:2019, in Console._check_buffer(self)
#    2016     return
#    2018 try:
# -> 2019     self._write_buffer()
#    2020 except BrokenPipeError:
#    2021     self.on_broken_pipe()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\rich\console.py:2035, in Console._write_buffer(self)
#    2032 if self.is_jupyter:  # pragma: no cover
#    2033     from .jupyter import display
# -> 2035     display(self._buffer, self._render_buffer(self._buffer[:]))
#    2036     del self._buffer[:]
#    2037 else:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\rich\jupyter.py:91, in display(segments, text)
#      88 try:
#      89     from IPython.display import display as ipython_display
# ---> 91     ipython_display(jupyter_renderable)
#      92 except ModuleNotFoundError:
#      93     # Handle the case where the Console has force_jupyter=True,
#      94     # but IPython is not installed.
#      95     pass
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\display_functions.py:285, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     282         if metadata:
#     283             # kwarg-specified metadata gets precedence
#     284             _merge(md_dict, metadata)
# --> 285         publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#     286 if display_id:
#     287     return DisplayHandle(display_id)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\display_functions.py:73, in publish_display_data(data, metadata, transient, **kwargs)
#      70 if transient:
#      71     kwargs['transient'] = transient
# ---> 73 display_pub.publish(
#      74     data=data,
#      75     metadata=metadata,
#      76     **kwargs
#      77 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\zmqshell.py:103, in ZMQDisplayPublisher.publish(self, data, metadata, transient, update)
#      81 def publish(
#      82     self,
#      83     data,
#    (...)     86     update=False,
#      87 ):
#      88     """Publish a display-data message
#      89
#      90     Parameters
#    (...)    101         If True, send an update_display_data message instead of display_data.
#     102     """
# --> 103     self._flush_streams()
#     104     if metadata is None:
#     105         metadata = {}
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\zmqshell.py:66, in ZMQDisplayPublisher._flush_streams(self)
#      64 def _flush_streams(self):
#      65     """flush IO Streams prior to display"""
# ---> 66     sys.stdout.flush()
#      67     sys.stderr.flush()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\rich\file_proxy.py:53, in FileProxy.flush(self)
#      51 output = "".join(self.__buffer)
#      52 if output:
# ---> 53     self.__console.print(output)
#      54 del self.__buffer[:]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\rich\console.py:1678, in Console.print(self, sep, end, style, justify, overflow, no_wrap, emoji, markup, highlight, width, height, crop, soft_wrap, new_line_start, *objects)
#    1676     crop = False
#    1677 render_hooks = self._render_hooks[:]
# -> 1678 with self:
#    1679     renderables = self._collect_renderables(
#    1680         objects,
#    1681         sep,
#    (...)   1686         highlight=highlight,
#    1687     )
#    1688     for hook in render_hooks:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\rich\console.py:864, in Console.__exit__(self, exc_type, exc_value, traceback)
#     862 def __exit__(self, exc_type: Any, exc_value: Any, traceback: Any) -> None:
#     863     """Exit buffer context."""
# --> 864     self._exit_buffer()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\rich\console.py:822, in Console._exit_buffer(self)
#     820 """Leave buffer context, and render content if required."""
#     821 self._buffer_index -= 1
# --> 822 self._check_buffer()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\rich\console.py:2019, in Console._check_buffer(self)
#    2016     return
#    2018 try:
# -> 2019     self._write_buffer()
#    2020 except BrokenPipeError:
#    2021     self.on_broken_pipe()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\rich\console.py:2035, in Console._write_buffer(self)
#    2032 if self.is_jupyter:  # pragma: no cover
#    2033     from .jupyter import display
# -> 2035     display(self._buffer, self._render_buffer(self._buffer[:]))
#    2036     del self._buffer[:]
#    2037 else:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\rich\jupyter.py:91, in display(segments, text)
#      88 try:
#      89     from IPython.display import display as ipython_display
# ---> 91     ipython_display(jupyter_renderable)
#      92 except ModuleNotFoundError:
#      93     # Handle the case where the Console has force_jupyter=True,
#      94     # but IPython is not installed.
#      95     pass
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\display_functions.py:285, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     282         if metadata:
#     283             # kwarg-specified metadata gets precedence
#     284             _merge(md_dict, metadata)
# --> 285         publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#     286 if display_id:
#     287     return DisplayHandle(display_id)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\display_functions.py:73, in publish_display_data(data, metadata, transient, **kwargs)
#      70 if transient:
#      71     kwargs['transient'] = transient
# ---> 73 display_pub.publish(
#      74     data=data,
#      75     metadata=metadata,
#      76     **kwargs
#      77 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\zmqshell.py:103, in ZMQDisplayPublisher.publish(self, data, metadata, transient, update)
#      81 def publish(
#      82     self,
#      83     data,
#    (...)     86     update=False,
#      87 ):
#      88     """Publish a display-data message
#      89
#      90     Parameters
#    (...)    101         If True, send an update_display_data message instead of display_data.
#     102     """
# --> 103     self._flush_streams()
#     104     if metadata is None:
#     105         metadata = {}
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\zmqshell.py:66, in ZMQDisplayPublisher._flush_streams(self)
#      64 def _flush_streams(self):
#      65     """flush IO Streams prior to display"""
# ---> 66     sys.stdout.flush()
#      67     sys.stderr.flush()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\rich\file_proxy.py:53, in FileProxy.flush(self)
#      51 output = "".join(self.__buffer)
#      52 if output:
# ---> 53     self.__console.print(output)
#      54 del self.__buffer[:]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\rich\console.py:1678, in Console.print(self, sep, end, style, justify, overflow, no_wrap, emoji, markup, highlight, width, height, crop, soft_wrap, new_line_start, *objects)
#    1676     crop = False
#    1677 render_hooks = self._render_hooks[:]
# -> 1678 with self:
#    1679     renderables = self._collect_renderables(
#    1680         objects,
#    1681         sep,
#    (...)   1686         highlight=highlight,
#    1687     )
#    1688     for hook in render_hooks:
#
#     [... skipping similar frames: Console.__exit__ at line 864 (266 times), Console._check_buffer at line 2019 (266 times), Console._exit_buffer at line 822 (266 times), Console._write_buffer at line 2035 (266 times), display at line 91 (266 times), ZMQDisplayPublisher._flush_streams at line 66 (265 times), display at line 285 (265 times), FileProxy.flush at line 53 (265 times), Console.print at line 1678 (265 times), ZMQDisplayPublisher.publish at line 103 (265 times), publish_display_data at line 73 (265 times)]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\display_functions.py:285, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     282         if metadata:
#     283             # kwarg-specified metadata gets precedence
#     284             _merge(md_dict, metadata)
# --> 285         publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#     286 if display_id:
#     287     return DisplayHandle(display_id)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\display_functions.py:73, in publish_display_data(data, metadata, transient, **kwargs)
#      70 if transient:
#      71     kwargs['transient'] = transient
# ---> 73 display_pub.publish(
#      74     data=data,
#      75     metadata=metadata,
#      76     **kwargs
#      77 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\zmqshell.py:103, in ZMQDisplayPublisher.publish(self, data, metadata, transient, update)
#      81 def publish(
#      82     self,
#      83     data,
#    (...)     86     update=False,
#      87 ):
#      88     """Publish a display-data message
#      89
#      90     Parameters
#    (...)    101         If True, send an update_display_data message instead of display_data.
#     102     """
# --> 103     self._flush_streams()
#     104     if metadata is None:
#     105         metadata = {}
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\zmqshell.py:66, in ZMQDisplayPublisher._flush_streams(self)
#      64 def _flush_streams(self):
#      65     """flush IO Streams prior to display"""
# ---> 66     sys.stdout.flush()
#      67     sys.stderr.flush()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\rich\file_proxy.py:53, in FileProxy.flush(self)
#      51 output = "".join(self.__buffer)
#      52 if output:
# ---> 53     self.__console.print(output)
#      54 del self.__buffer[:]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\rich\console.py:1678, in Console.print(self, sep, end, style, justify, overflow, no_wrap, emoji, markup, highlight, width, height, crop, soft_wrap, new_line_start, *objects)
#    1676     crop = False
#    1677 render_hooks = self._render_hooks[:]
# -> 1678 with self:
#    1679     renderables = self._collect_renderables(
#    1680         objects,
#    1681         sep,
#    (...)   1686         highlight=highlight,
#    1687     )
#    1688     for hook in render_hooks:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\rich\console.py:864, in Console.__exit__(self, exc_type, exc_value, traceback)
#     862 def __exit__(self, exc_type: Any, exc_value: Any, traceback: Any) -> None:
#     863     """Exit buffer context."""
# --> 864     self._exit_buffer()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\rich\console.py:822, in Console._exit_buffer(self)
#     820 """Leave buffer context, and render content if required."""
#     821 self._buffer_index -= 1
# --> 822 self._check_buffer()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\rich\console.py:2019, in Console._check_buffer(self)
#    2016     return
#    2018 try:
# -> 2019     self._write_buffer()
#    2020 except BrokenPipeError:
#    2021     self.on_broken_pipe()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\rich\console.py:2035, in Console._write_buffer(self)
#    2032 if self.is_jupyter:  # pragma: no cover
#    2033     from .jupyter import display
# -> 2035     display(self._buffer, self._render_buffer(self._buffer[:]))
#    2036     del self._buffer[:]
#    2037 else:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\rich\jupyter.py:91, in display(segments, text)
#      88 try:
#      89     from IPython.display import display as ipython_display
# ---> 91     ipython_display(jupyter_renderable)
#      92 except ModuleNotFoundError:
#      93     # Handle the case where the Console has force_jupyter=True,
#      94     # but IPython is not installed.
#      95     pass
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\display_functions.py:278, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     276     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     277 else:
# --> 278     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     279     if not format_dict:
#     280         # nothing to display (e.g. _ipython_display_ took over)
#     281         continue
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\formatters.py:204, in DisplayFormatter.format(self, obj, include, exclude)
#     201 format_dict = {}
#     202 md_dict = {}
# --> 204 if self.ipython_display_formatter(obj):
#     205     # object handled itself, don't proceed
#     206     return {}, {}
#     208 format_dict, md_dict = self.mimebundle_formatter(obj, include=include, exclude=exclude)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\decorator.py:235, in decorate.<locals>.fun(*args, **kw)
#     233 if not kwsyntax:
#     234     args, kw = fix(args, kw, sig)
# --> 235 return caller(func, *(extras + args), **kw)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\formatters.py:290, in catch_format_error(method, self, *args, **kwargs)
#     288 ip = get_ipython()
#     289 if ip is not None:
# --> 290     ip.showtraceback(exc_info)
#     291 else:
#     292     traceback.print_exception(*exc_info)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py:2164, in InteractiveShell.showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2159         return False
#    2160     return isinstance(
#    2161         val, BaseExceptionGroup
#    2162     ) or contains_exceptiongroup(val.__context__)
# -> 2164 if contains_exceptiongroup(value):
#    2165     # fall back to native exception formatting until ultratb
#    2166     # supports exception groups
#    2167     traceback.print_exc()
#    2168 else:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py:2162, in InteractiveShell.showtraceback.<locals>.contains_exceptiongroup(val)
#    2158 if val is None:
#    2159     return False
#    2160 return isinstance(
#    2161     val, BaseExceptionGroup
# -> 2162 ) or contains_exceptiongroup(val.__context__)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py:2162, in InteractiveShell.showtraceback.<locals>.contains_exceptiongroup(val)
#    2158 if val is None:
#    2159     return False
#    2160 return isinstance(
#    2161     val, BaseExceptionGroup
# -> 2162 ) or contains_exceptiongroup(val.__context__)
#
#     [... skipping similar frames: InteractiveShell.showtraceback.<locals>.contains_exceptiongroup at line 2162 (2 times)]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py:2162, in InteractiveShell.showtraceback.<locals>.contains_exceptiongroup(val)
#    2158 if val is None:
#    2159     return False
#    2160 return isinstance(
#    2161     val, BaseExceptionGroup
# -> 2162 ) or contains_exceptiongroup(val.__context__)
#
# RecursionError: maximum recursion depth exceeded

# %%
# ✅ Install required packages if not already installed (only if running locally)
# !pip install crewai==0.28.8 crewai_tools==0.1.6 langchain_community==0.0.29

# ✅ Setup
import os
import warnings
warnings.filterwarnings('ignore')

from crewai import Agent, Task, Crew
from utils import get_openai_api_key
openai_api_key = get_openai_api_key()
os.environ["OPENAI_MODEL_NAME"] = "gpt-3.5-turbo"

# ✅ Define Agents

planner = Agent(
    role="Content Planner",
    goal="Plan informative, well-structured, and audience-friendly content on {topic}",
    backstory="You're a planner creating a content structure with Introduction, What/Why/Where, Benefits, Applications, and Conclusion for a blog post on {topic}.",
    allow_delegation=False,
    verbose=True
)

writer = Agent(
    role="Content Writer",
    goal="Write clear, helpful, and easy-to-understand content based on the planner's outline",
    backstory="You're a writer drafting content based on the planner's structure using simple language and informative insights.",
    allow_delegation=False,
    verbose=True
)

editor = Agent(
    role="Content Editor",
    goal="Edit and enhance the clarity, tone, grammar, and structure of the article",
    backstory="You're an editor reviewing and improving the written content to ensure readability, correct grammar, and adherence to structure.",
    allow_delegation=False,
    verbose=True
)

plag_checker = Agent(
    role="Plagiarism Checker",
    goal="Check the article for any copied content and ensure originality",
    backstory="You're responsible for verifying that the content is original and flagging or suggesting changes to any potentially plagiarized segments.",
    allow_delegation=False,
    verbose=True
)

# ✅ Define Tasks

plan = Task(
    description=(
        "Create a content outline for a blog post on {topic} using this structure:\n"
        "1. Introduction\n"
        "2. What, Why, and Where\n"
        "3. Benefits\n"
        "4. Applications\n"
        "5. Conclusion\n"
        "Also include SEO keywords and target audience insights."
    ),
    expected_output="A content plan including an outline, SEO keywords, and target audience.",
    agent=planner,
)

write = Task(
    description=(
        "Write a clear and informative blog post on {topic} using the planner's outline. "
        "Use easy language. Ensure each section (Intro, What/Why/Where, Benefits, Applications, Conclusion) is 2-3 paragraphs long."
    ),
    expected_output="A draft article in markdown format with 5 sections, each having 2-3 paragraphs.",
    agent=writer,
)

check = Task(
    description=(
        "Scan the written content for plagiarism. Identify any potentially copied phrases and suggest replacements. "
        "Ensure the article is safe for publishing."
    ),
    expected_output="A markdown report with plagiarism findings and recommendations if needed.",
    agent=plag_checker,
)

edit = Task(
    description=(
        "Proofread the article. Improve clarity, structure, and grammar. Ensure tone is friendly and helpful. "
        "Make sure the blog matches the 5-part structure and is engaging to read."
    ),
    expected_output="Final edited article in markdown format, clean and reader-friendly.",
    agent=editor,
)

# ✅ Create Crew
crew = Crew(
    agents=[planner, writer, plag_checker, editor],
    tasks=[plan, write, check, edit],
      # Shows detailed logs
)

# ✅ Run the Agent System
result = crew.kickoff(inputs={"topic": "Art"})

# ✅ Show the Result
from IPython.display import Markdown
Markdown(result)
# Out:
# # Agent: Content Planner
# ## Task: Create a content outline for a blog post on Art using this structure:
# 1. Introduction
# 2. What, Why, and Where
# 3. Benefits
# 4. Applications
# 5. Conclusion
# Also include SEO keywords and target audience insights.
#
#
#
#
#
#  An unknown error occurred. Please check the details below.
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\litellm\llms\openai\openai.py:724, in OpenAIChatCompletion.completion(self, model_response, timeout, optional_params, litellm_params, logging_obj, model, messages, print_verbose, api_key, api_base, api_version, dynamic_params, azure_ad_token, acompletion, logger_fn, headers, custom_prompt_dict, client, organization, custom_llm_provider, drop_params)
#     723             else:
# --> 724                 raise e
#     725 except OpenAIError as e:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\litellm\llms\openai\openai.py:626, in OpenAIChatCompletion.completion(self, model_response, timeout, optional_params, litellm_params, logging_obj, model, messages, print_verbose, api_key, api_base, api_version, dynamic_params, azure_ad_token, acompletion, logger_fn, headers, custom_prompt_dict, client, organization, custom_llm_provider, drop_params)
#     623     raise OpenAIError(
#     624         status_code=422, message="max retries must be an int"
#     625     )
# --> 626 openai_client: OpenAI = self._get_openai_client(  # type: ignore
#     627     is_async=False,
#     628     api_key=api_key,
#     629     api_base=api_base,
#     630     api_version=api_version,
#     631     timeout=timeout,
#     632     max_retries=max_retries,
#     633     organization=organization,
#     634     client=client,
#     635 )
#     637 ## LOGGING
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\litellm\llms\openai\openai.py:377, in OpenAIChatCompletion._get_openai_client(self, is_async, api_key, api_base, api_version, timeout, max_retries, organization, client)
#     376 else:
# --> 377     _new_client = OpenAI(
#     378         api_key=api_key,
#     379         base_url=api_base,
#     380         http_client=OpenAIChatCompletion._get_sync_http_client(),
#     381         timeout=timeout,
#     382         max_retries=max_retries,
#     383         organization=organization,
#     384     )
#     386 ## SAVE CACHE KEY
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\openai\_client.py:116, in OpenAI.__init__(self, api_key, organization, project, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     115 if api_key is None:
# --> 116     raise OpenAIError(
#     117         "The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     118     )
#     119 self.api_key = api_key
#
# OpenAIError: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable
#
# During handling of the above exception, another exception occurred:
#
# OpenAIError                               Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\litellm\main.py:1831, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, deployment_id, extra_headers, functions, function_call, base_url, api_version, api_key, model_list, thinking, **kwargs)
#    1825     logging.post_call(
#    1826         input=messages,
#    1827         api_key=api_key,
#    1828         original_response=str(e),
#    1829         additional_args={"headers": headers},
#    1830     )
# -> 1831     raise e
#    1833 if optional_params.get("stream", False):
#    1834     ## LOGGING
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\litellm\main.py:1804, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, deployment_id, extra_headers, functions, function_call, base_url, api_version, api_key, model_list, thinking, **kwargs)
#    1803 try:
# -> 1804     response = openai_chat_completions.completion(
#    1805         model=model,
#    1806         messages=messages,
#    1807         headers=headers,
#    1808         model_response=model_response,
#    1809         print_verbose=print_verbose,
#    1810         api_key=api_key,
#    1811         api_base=api_base,
#    1812         acompletion=acompletion,
#    1813         logging_obj=logging,
#    1814         optional_params=optional_params,
#    1815         litellm_params=litellm_params,
#    1816         logger_fn=logger_fn,
#    1817         timeout=timeout,  # type: ignore
#    1818         custom_prompt_dict=custom_prompt_dict,
#    1819         client=client,  # pass AsyncOpenAI, OpenAI client
#    1820         organization=organization,
#    1821         custom_llm_provider=custom_llm_provider,
#    1822     )
#    1823 except Exception as e:
#    1824     ## LOGGING - log the original exception returned
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\litellm\llms\openai\openai.py:735, in OpenAIChatCompletion.completion(self, model_response, timeout, optional_params, litellm_params, logging_obj, model, messages, print_verbose, api_key, api_base, api_version, dynamic_params, azure_ad_token, acompletion, logger_fn, headers, custom_prompt_dict, client, organization, custom_llm_provider, drop_params)
#     734     error_headers = getattr(error_response, "headers", None)
# --> 735 raise OpenAIError(
#     736     status_code=status_code,
#     737     message=error_text,
#     738     headers=error_headers,
#     739     body=error_body,
#     740 )
#
# OpenAIError: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable
#
# During handling of the above exception, another exception occurred:
#
# AuthenticationError                       Traceback (most recent call last)
# Cell In[4], line 99
#      92 crew = Crew(
#      93     agents=[planner, writer, plag_checker, editor],
#      94     tasks=[plan, write, check, edit],
#      95       # Shows detailed logs
#      96 )
#      98 # ✅ Run the Agent System
# ---> 99 result = crew.kickoff(inputs={"topic": "Art"})
#     101 # ✅ Show the Result
#     102 from IPython.display import Markdown
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\crewai\crew.py:661, in Crew.kickoff(self, inputs)
#     658 metrics: List[UsageMetrics] = []
#     660 if self.process == Process.sequential:
# --> 661     result = self._run_sequential_process()
#     662 elif self.process == Process.hierarchical:
#     663     result = self._run_hierarchical_process()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\crewai\crew.py:773, in Crew._run_sequential_process(self)
#     771 def _run_sequential_process(self) -> CrewOutput:
#     772     """Executes tasks sequentially and returns the final output."""
# --> 773     return self._execute_tasks(self.tasks)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\crewai\crew.py:876, in Crew._execute_tasks(self, tasks, start_index, was_replayed)
#     873     futures.clear()
#     875 context = self._get_context(task, task_outputs)
# --> 876 task_output = task.execute_sync(
#     877     agent=agent_to_use,
#     878     context=context,
#     879     tools=cast(List[BaseTool], tools_for_task),
#     880 )
#     881 task_outputs.append(task_output)
#     882 self._process_task_result(task, task_output)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\crewai\task.py:351, in Task.execute_sync(self, agent, context, tools)
#     344 def execute_sync(
#     345     self,
#     346     agent: Optional[BaseAgent] = None,
#     347     context: Optional[str] = None,
#     348     tools: Optional[List[BaseTool]] = None,
#     349 ) -> TaskOutput:
#     350     """Execute the task synchronously."""
# --> 351     return self._execute_core(agent, context, tools)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\crewai\task.py:495, in Task._execute_core(self, agent, context, tools)
#     493 self.end_time = datetime.datetime.now()
#     494 crewai_event_bus.emit(self, TaskFailedEvent(error=str(e), task=self))
# --> 495 raise e
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\crewai\task.py:415, in Task._execute_core(self, agent, context, tools)
#     413 self.processed_by_agents.add(agent.role)
#     414 crewai_event_bus.emit(self, TaskStartedEvent(context=context, task=self))
# --> 415 result = agent.execute_task(
#     416     task=self,
#     417     context=context,
#     418     tools=tools,
#     419 )
#     421 pydantic_output, json_output = self._export_output(result)
#     422 task_output = TaskOutput(
#     423     name=self.name,
#     424     description=self.description,
#    (...)    430     output_format=self._get_output_format(),
#     431 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\crewai\agent.py:420, in Agent.execute_task(self, task, context, tools)
#     410 if e.__class__.__module__.startswith("litellm"):
#     411     # Do not retry on litellm errors
#     412     crewai_event_bus.emit(
#     413         self,
#     414         event=AgentExecutionErrorEvent(
#    (...)    418         ),
#     419     )
# --> 420     raise e
#     421 self._times_executed += 1
#     422 if self._times_executed > self.max_retry_limit:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\crewai\agent.py:396, in Agent.execute_task(self, task, context, tools)
#     392         result = self._execute_with_timeout(
#     393             task_prompt, task, self.max_execution_time
#     394         )
#     395     else:
# --> 396         result = self._execute_without_timeout(task_prompt, task)
#     398 except TimeoutError as e:
#     399     # Propagate TimeoutError without retry
#     400     crewai_event_bus.emit(
#     401         self,
#     402         event=AgentExecutionErrorEvent(
#    (...)    406         ),
#     407     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\crewai\agent.py:492, in Agent._execute_without_timeout(self, task_prompt, task)
#     482 def _execute_without_timeout(self, task_prompt: str, task: Task) -> str:
#     483     """Execute a task without a timeout.
#     484
#     485     Args:
#    (...)    490         The output of the agent.
#     491     """
# --> 492     return self.agent_executor.invoke(
#     493         {
#     494             "input": task_prompt,
#     495             "tool_names": self.agent_executor.tools_names,
#     496             "tools": self.agent_executor.tools_description,
#     497             "ask_for_human_input": task.human_input,
#     498         }
#     499     )["output"]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\crewai\agents\crew_agent_executor.py:121, in CrewAgentExecutor.invoke(self, inputs)
#     118 handle_unknown_error(self._printer, e)
#     119 if e.__class__.__module__.startswith("litellm"):
#     120     # Do not retry on litellm errors
# --> 121     raise e
#     122 else:
#     123     raise e
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\crewai\agents\crew_agent_executor.py:110, in CrewAgentExecutor.invoke(self, inputs)
#     107 self.ask_for_human_input = bool(inputs.get("ask_for_human_input", False))
#     109 try:
# --> 110     formatted_answer = self._invoke_loop()
#     111 except AssertionError:
#     112     self._printer.print(
#     113         content="Agent failed to reach a final answer. This is likely a bug - please report it.",
#     114         color="red",
#     115     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\crewai\agents\crew_agent_executor.py:206, in CrewAgentExecutor._invoke_loop(self)
#     203 except Exception as e:
#     204     if e.__class__.__module__.startswith("litellm"):
#     205         # Do not retry on litellm errors
# --> 206         raise e
#     207     if is_context_length_exceeded(e):
#     208         handle_context_length(
#     209             respect_context_window=self.respect_context_window,
#     210             printer=self._printer,
#    (...)    214             i18n=self._i18n,
#     215         )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\crewai\agents\crew_agent_executor.py:153, in CrewAgentExecutor._invoke_loop(self)
#     142     formatted_answer = handle_max_iterations_exceeded(
#     143         formatted_answer,
#     144         printer=self._printer,
#    (...)    148         callbacks=self.callbacks,
#     149     )
#     151 enforce_rpm_limit(self.request_within_rpm_limit)
# --> 153 answer = get_llm_response(
#     154     llm=self.llm,
#     155     messages=self.messages,
#     156     callbacks=self.callbacks,
#     157     printer=self._printer,
#     158 )
#     159 formatted_answer = process_llm_response(answer, self.use_stop_words)
#     161 if isinstance(formatted_answer, AgentAction):
#     162     # Extract agent fingerprint if available
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\crewai\utilities\agent_utils.py:157, in get_llm_response(llm, messages, callbacks, printer)
#     152 except Exception as e:
#     153     printer.print(
#     154         content=f"Error during LLM call: {e}",
#     155         color="red",
#     156     )
# --> 157     raise e
#     158 if not answer:
#     159     printer.print(
#     160         content="Received None or empty response from LLM call.",
#     161         color="red",
#     162     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\crewai\utilities\agent_utils.py:148, in get_llm_response(llm, messages, callbacks, printer)
#     146 """Call the LLM and return the response, handling any invalid responses."""
#     147 try:
# --> 148     answer = llm.call(
#     149         messages,
#     150         callbacks=callbacks,
#     151     )
#     152 except Exception as e:
#     153     printer.print(
#     154         content=f"Error during LLM call: {e}",
#     155         color="red",
#     156     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\crewai\llm.py:924, in LLM.call(self, messages, tools, callbacks, available_functions)
#     920         return self._handle_streaming_response(
#     921             params, callbacks, available_functions
#     922         )
#     923     else:
# --> 924         return self._handle_non_streaming_response(
#     925             params, callbacks, available_functions
#     926         )
#     928 except LLMContextLengthExceededException:
#     929     # Re-raise LLMContextLengthExceededException as it should be handled
#     930     # by the CrewAgentExecutor._invoke_loop method, which can then decide
#     931     # whether to summarize the content or abort based on the respect_context_window flag
#     932     raise
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\crewai\llm.py:763, in LLM._handle_non_streaming_response(self, params, callbacks, available_functions)
#     757 # --- 1) Make the completion call
#     758 try:
#     759     # Attempt to make the completion call, but catch context window errors
#     760     # and convert them to our own exception type for consistent handling
#     761     # across the codebase. This allows CrewAgentExecutor to handle context
#     762     # length issues appropriately.
# --> 763     response = litellm.completion(**params)
#     764 except ContextWindowExceededError as e:
#     765     # Convert litellm's context window error to our own exception type
#     766     # for consistent handling in the rest of the codebase
#     767     raise LLMContextLengthExceededException(str(e))
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\litellm\utils.py:1255, in client.<locals>.wrapper(*args, **kwargs)
#    1251 if logging_obj:
#    1252     logging_obj.failure_handler(
#    1253         e, traceback_exception, start_time, end_time
#    1254     )  # DO NOT MAKE THREADED - router retry fallback relies on this!
# -> 1255 raise e
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\litellm\utils.py:1133, in client.<locals>.wrapper(*args, **kwargs)
#    1131         print_verbose(f"Error while checking max token limit: {str(e)}")
#    1132 # MODEL CALL
# -> 1133 result = original_function(*args, **kwargs)
#    1134 end_time = datetime.datetime.now()
#    1135 if "stream" in kwargs and kwargs["stream"] is True:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\litellm\main.py:3216, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, deployment_id, extra_headers, functions, function_call, base_url, api_version, api_key, model_list, thinking, **kwargs)
#    3213     return response
#    3214 except Exception as e:
#    3215     ## Map to OpenAI Exception
# -> 3216     raise exception_type(
#    3217         model=model,
#    3218         custom_llm_provider=custom_llm_provider,
#    3219         original_exception=e,
#    3220         completion_kwargs=args,
#    3221         extra_kwargs=kwargs,
#    3222     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\litellm\litellm_core_utils\exception_mapping_utils.py:2224, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#    2222 if exception_mapping_worked:
#    2223     setattr(e, "litellm_response_headers", litellm_response_headers)
# -> 2224     raise e
#    2225 else:
#    2226     for error_type in litellm.LITELLM_EXCEPTION_TYPES:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\litellm\litellm_core_utils\exception_mapping_utils.py:363, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#     358 elif (
#     359     "The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     360     in error_str
#     361 ):
#     362     exception_mapping_worked = True
# --> 363     raise AuthenticationError(
#     364         message=f"AuthenticationError: {exception_provider} - {message}",
#     365         llm_provider=custom_llm_provider,
#     366         model=model,
#     367         response=getattr(original_exception, "response", None),
#     368         litellm_debug_info=extra_information,
#     369     )
#     370 elif "Mistral API raised a streaming error" in error_str:
#     371     exception_mapping_worked = True
#
# AuthenticationError: litellm.AuthenticationError: AuthenticationError: OpenAIException - The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable
